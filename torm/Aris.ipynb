# %%
from pandas import read_csv
from pandas import read_excel
from pandas import datetime
import xlwings as xw
from matplotlib import pyplot

def parser(x):
    x = x.split(" ")[0]
    return datetime.strptime(x, '%Y-%m-%d')

print parser('2014-01-09 00:00:00.000')

#date_str = "2014-01-09 00:00:00.000"
#date_str = date_str.split(" ")[0]
#date = datetime.strptime(date_str, '%Y-%m-%d')
#date.month
##Continue here:
#1. Write datetime parser
#2. Get averages for each month
#3. Run ARIMA

#series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#autocorrelation_plot(series)
#pyplot.show()
# Out:
# 2014-01-09 00:00:00

# %%
series = read_excel(r'C:\Users\agzid\OneDrive - Danmarks Tekniske Universitet\TORM\Data\trends.xlsx', sheet_name='Spot', index_col = 2, parse_dates=[2], date_parser=parser)
#wb = xw.Book(r'C:\Users\Porter\OneDrive - Danmarks Tekniske Universitet\Christian Bertram\MDM.xlsx')
series
# Out:
#              CMSRouteId  RouteAverage, price
# ArchiveDate
# 2014-01-07         TC14              116.790
# 2014-01-08         TC14              116.430
# 2014-01-09         TC14              110.000
# 2014-01-10         TC14              109.290
# 2014-01-13         TC14              106.790
# 2014-01-14         TC14               88.210
# 2014-01-15         TC14               83.210
# 2014-01-16         TC14               83.930
# 2014-01-17         TC14               83.930
# 2014-01-20         TC14               83.390
# 2014-01-21         TC14               81.820
# 2014-01-22         TC14               78.330
# 2014-01-23         TC14               81.430
# 2014-01-24         TC14               80.000
# 2014-01-27         TC14               80.000
# 2014-01-28         TC14               77.860
# 2014-01-29         TC14               75.710
# 2014-01-30         TC14               75.360
# 2014-01-31         TC14               76.070
# ...
