# %%
print "Hello World"
# Out:
# Hello World

# %%
import csv
import pandas

import json

csvfile = open('thetable_forjson.csv', 'r')
jsonfile = open('file.json', 'w')

fieldnames = ("source","target","id","city","lat","lon","last_old")
reader = csv.DictReader( csvfile, fieldnames)
for row in reader:
    json.dump(row, jsonfile)
    jsonfile.write('\n')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-9818163c7516> in <module>()
#       4 import json
#       5
# ----> 6 csvfile = open('thetable_forjson.csv', 'r')
#       7 jsonfile = open('file.json', 'w')
#       8
#
# IOError: [Errno 2] No such file or directory: 'thetable_forjson.csv'

# %%
sel = data[(data["OFNS_DESC"].str.contains("MURDER")) & (data["CMPLNT_FR_DT"].str.contains("2016"))]
sel
# Out:
#         CMPLNT_FR_DT CMPLNT_FR_TM                        OFNS_DESC  \
# 5101930   12/31/2016     01:05:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5103068   12/30/2016     00:40:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5107748   12/26/2016     12:45:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5107854   12/26/2016     08:14:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5107855   12/26/2016     08:14:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5108627   12/25/2016     12:51:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5114269   12/20/2016     20:24:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5115641   12/19/2016     18:00:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5117003   12/18/2016     15:31:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5118455   12/17/2016     02:20:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5121311   12/14/2016     18:45:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5121901   12/01/2016     19:00:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5122650   12/13/2016     20:45:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5122770   12/13/2016     18:21:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5125199   12/11/2016     20:29:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5125524   12/11/2016     12:22:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5125897   12/11/2016     00:20:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5128140   12/09/2016     01:50:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5130465   12/07/2016     15:02:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5133479   12/05/2016     00:15:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5134115   12/04/2016     21:17:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5135252   12/03/2016     20:35:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5139735   11/30/2016     10:24:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5139932   11/30/2016     02:00:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5139969   11/30/2016     00:43:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5141731   11/28/2016     23:19:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5142052   11/28/2016     14:50:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5143102   11/27/2016     20:30:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5144185   11/26/2016     21:07:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5144612   11/26/2016     12:00:00  MURDER & NON-NEGL. MANSLAUGHTER
# ...              ...          ...                              ...
# 5526474   02/13/2016     03:00:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5528206   02/11/2016     21:39:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5529260   02/10/2016     08:54:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5529781   02/10/2016     08:54:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5530009   02/10/2016     08:54:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5532624   02/08/2016     02:21:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5535538   02/05/2016     21:35:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5535618   02/05/2016     19:15:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5547233   01/20/2016     16:35:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5547289   01/27/2016     23:40:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5547859   01/27/2016     10:50:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5551006   01/24/2016     16:07:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5551524   01/23/2016     19:54:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5552699   01/22/2016     09:07:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5553484   01/21/2016     20:30:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5554466   01/10/2016     22:06:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5558574   01/17/2016     21:17:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5560066   01/16/2016     15:15:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5560572   01/16/2016     00:40:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5562837   01/14/2016     14:36:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5564159   01/13/2016     14:48:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5566757   01/11/2016     13:29:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5566910   01/11/2016     09:08:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5566967   01/11/2016     07:40:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5568266   01/10/2016     03:32:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5568784   01/09/2016     23:22:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5573574   01/06/2016     08:21:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5575826   01/04/2016     11:00:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5575942   01/04/2016     04:25:00  MURDER & NON-NEGL. MANSLAUGHTER
# 5578703   01/01/2016     22:55:00  MURDER & NON-NEGL. MANSLAUGHTER
#
#                BORO_NM   Latitude  Longitude
# 5101930       BROOKLYN  40.648265 -73.955752
# 5103068          BRONX  40.837322 -73.910117
# 5107748  STATEN ISLAND  40.624237 -74.080756
# 5107854      MANHATTAN  40.832111 -73.948294
# 5107855      MANHATTAN  40.832111 -73.948294
# 5108627       BROOKLYN  40.646328 -73.929804
# 5114269          BRONX  40.839872 -73.888140
# 5115641      MANHATTAN  40.806618 -73.936766
# 5117003       BROOKLYN  40.657587 -73.929054
# 5118455      MANHATTAN  40.753875 -73.984820
# 5121311      MANHATTAN  40.809413 -73.944367
# 5121901          BRONX  40.841691 -73.837040
# 5122650          BRONX  40.820986 -73.892229
# 5122770       BROOKLYN  40.679066 -73.915067
# 5125199          BRONX  40.845985 -73.907463
# 5125524         QUEENS  40.669758 -73.802652
# 5125897       BROOKLYN  40.703807 -73.952859
# 5128140      MANHATTAN  40.799086 -73.947619
# 5130465       BROOKLYN  40.638689 -73.916812
# 5133479         QUEENS  40.689141 -73.820855
# 5134115       BROOKLYN  40.626986 -73.914017
# 5135252          BRONX  40.837684 -73.913257
# 5139735       BROOKLYN  40.667863 -73.905388
# 5139932         QUEENS  40.691197 -73.835461
# 5139969       BROOKLYN  40.667533 -73.864248
# 5141731      MANHATTAN  40.849776 -73.937527
# 5142052          BRONX  40.823424 -73.901583
# 5143102      MANHATTAN  40.790325 -73.941711
# 5144185  STATEN ISLAND  40.621066 -74.084955
# 5144612          BRONX  40.874181 -73.833872
# ...                ...        ...        ...
# 5526474      MANHATTAN  40.817503 -73.941976
# 5528206       BROOKLYN  40.662693 -73.888307
# 5529260  STATEN ISLAND  40.608392 -74.146612
# 5529781  STATEN ISLAND  40.608392 -74.146612
# 5530009  STATEN ISLAND  40.608392 -74.146612
# 5532624          BRONX  40.853064 -73.868945
# 5535538         QUEENS  40.750332 -73.792131
# 5535618          BRONX  40.827669 -73.925436
# 5547233       BROOKLYN  40.706860 -73.948197
# 5547289      MANHATTAN  40.803394 -73.938145
# 5547859         QUEENS  40.596214 -73.764700
# 5551006          BRONX  40.811393 -73.922315
# 5551524       BROOKLYN  40.644590 -74.001900
# 5552699       BROOKLYN  40.684792 -73.878557
# 5553484          BRONX  40.857923 -73.892896
# 5554466       BROOKLYN  40.676232 -74.006945
# 5558574       BROOKLYN  40.576124 -73.999825
# 5560066       BROOKLYN  40.661080 -73.894823
# 5560572  STATEN ISLAND  40.606405 -74.120479
# 5562837  STATEN ISLAND  40.548991 -74.230271
# 5564159       BROOKLYN  40.664760 -73.894042
# 5566757       BROOKLYN  40.679908 -73.920784
# 5566910       BROOKLYN  40.681907 -73.894588
# 5566967         QUEENS  40.676487 -73.837065
# 5568266       BROOKLYN  40.683276 -73.930623
# 5568784       BROOKLYN  40.661562 -73.925946
# 5573574       BROOKLYN  40.674602 -73.938614
# 5575826          BRONX  40.873602 -73.845604
# 5575942          BRONX  40.883928 -73.901324
# 5578703         QUEENS  40.687141 -73.856146
#
# [314 rows x 6 columns]

# %%
sel.to_csv("murders2016.csv", encoding='utf-8', index=False)

# %%
sel['CMPLNT_FR_TM'] = pandas.to_datetime(sel['CMPLNT_FR_TM'])
sel
# Out:
# C:\Users\Porter\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         CMPLNT_FR_DT        CMPLNT_FR_TM                        OFNS_DESC  \
# 5101930   12/31/2016 2018-04-02 01:05:00  MURDER & NON-NEGL. MANSLAUGHTER
# 
# 5144612          BRONX  40.874181 -73.833872
# ...                ...        ...        ...
# 5526474      MANHATTAN  40.817503 -73.941976
# 5528206       BROOKLYN  40.662693 -73.888307
# 5529260  STATEN ISLAND  40.608392 -74.146612
# 5529781  STATEN ISLAND  40.608392 -74.146612
# 5530009  STATEN ISLAND  40.608392 -74.146612
# 5532624          BRONX  40.853064 -73.868945
# 5535538         QUEENS  40.750332 -73.792131
# 5535618          BRONX  40.827669 -73.925436
# 5547233       BROOKLYN  40.706860 -73.948197
# 5547289      MANHATTAN  40.803394 -73.938145
# 5547859         QUEENS  40.596214 -73.764700
# 5551006          BRONX  40.811393 -73.922315
# 5551524       BROOKLYN  40.644590 -74.001900
# 5552699       BROOKLYN  40.684792 -73.878557
# 5553484          BRONX  40.857923 -73.892896
# 5554466       BROOKLYN  40.676232 -74.006945
# 5558574       BROOKLYN  40.576124 -73.999825
# 5560066       BROOKLYN  40.661080 -73.894823
# 5560572  STATEN ISLAND  40.606405 -74.120479
# 5562837  STATEN ISLAND  40.548991 -74.230271
# 5564159       BROOKLYN  40.664760 -73.894042
# 5566757       BROOKLYN  40.679908 -73.920784
# 5566910       BROOKLYN  40.681907 -73.894588
# 5566967         QUEENS  40.676487 -73.837065
# 5568266       BROOKLYN  40.683276 -73.930623
# 5568784       BROOKLYN  40.661562 -73.925946
# 5573574       BROOKLYN  40.674602 -73.938614
# 5575826          BRONX  40.873602 -73.845604
# 5575942          BRONX  40.883928 -73.901324
# 5578703         QUEENS  40.687141 -73.856146
#
# [314 rows x 6 columns]

# %%
sel.to_csv("allmurderhours.csv", encoding='utf-8', index=False)

# %%
histo = sel.groupby(hours).count()
histo

# %%
forhisto = histo['CMPLNT_FR_DT']

# %%
forhisto.to_csv("murderhours.csv", encoding='utf-8')

# %%
crimes = sel.groupby(['OFNS_DESC']).count()
crimes
# Out:
#                                  CMPLNT_FR_DT  CMPLNT_FR_TM  BORO_NM  \
# OFNS_DESC
# MURDER & NON-NEGL. MANSLAUGHTER           314           314      314
#
#                                  Latitude  Longitude
# OFNS_DESC
# MURDER & NON-NEGL. MANSLAUGHTER       313        313

# %%
sortedCrimes = crimes.sort_values(by=['BORO_NM'], ascending=False)
sortedCrimes.head()
# Out:
#                                 RPT_DT  BORO_NM
# OFNS_DESC
# PETIT LARCENY                    24620    24620
# GRAND LARCENY                    16477    16477
# HARRASSMENT 2                    13245    13245
# ASSAULT 3 & RELATED OFFENSES     10418    10418
# CRIMINAL MISCHIEF & RELATED OF   10003    10003

# %%
petit = sel[(sel["OFNS_DESC"] == 'PETIT LARCENY')]
grand = sel[(sel["OFNS_DESC"] == 'GRAND LARCENY')]

# %%
harass = sel[(sel["OFNS_DESC"] == 'HARRASSMENT 2')]

# %%
assault = sel[(sel["OFNS_DESC"] == 'ASSAULT 3 & RELATED OFFENSES')]

# %%
criminal = sel[(sel["OFNS_DESC"] == 'CRIMINAL MISCHIEF & RELATED OF')]

# %%
petit['RPT_DT'] = pandas.to_datetime(petit['RPT_DT'])
# Out:
# C:\Users\Porter\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
grand['RPT_DT'] = pandas.to_datetime(grand['RPT_DT'])
# Out:
# C:\Users\Porter\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
assault['RPT_DT'] = pandas.to_datetime(assault['RPT_DT'])
# Out:
# C:\Users\Porter\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
harass['RPT_DT'] = pandas.to_datetime(harass['RPT_DT'])
# Out:
# C:\Users\Porter\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
criminal['RPT_DT'] = pandas.to_datetime(criminal['RPT_DT'])
# Out:
# C:\Users\Porter\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
petit.head()
# Out:
#             RPT_DT      OFNS_DESC    BORO_NM
# 5101380 2016-12-31  PETIT LARCENY  MANHATTAN
# 5101391 2016-12-31  PETIT LARCENY  MANHATTAN
# 5101458 2016-12-31  PETIT LARCENY  MANHATTAN
# 5101476 2016-12-31  PETIT LARCENY  MANHATTAN
# 5101495 2016-12-31  PETIT LARCENY  MANHATTAN

# %%
grand.head()
# Out:
#             RPT_DT      OFNS_DESC    BORO_NM
# 5101244 2016-12-31  GRAND LARCENY  MANHATTAN
# 5101245 2016-12-31  GRAND LARCENY  MANHATTAN
# 5101246 2016-12-31  GRAND LARCENY  MANHATTAN
# 5101255 2016-12-31  GRAND LARCENY  MANHATTAN
# 5101257 2016-12-31  GRAND LARCENY  MANHATTAN

# %%
petit.dtypes
# Out:
# RPT_DT       datetime64[ns]
# OFNS_DESC            object
# BORO_NM              object
# dtype: object

# %%
months = petit['RPT_DT'].dt.month

# %%
monthsg = grand['RPT_DT'].dt.month

# %%
monthsh = harass['RPT_DT'].dt.month

# %%
monthsa = assault['RPT_DT'].dt.month

# %%
monthsc = criminal['RPT_DT'].dt.month

# %%
from collections import Counter
Counter(months)
# Out:
# Counter({1L: 1976,
#          2L: 1774,
#          3L: 1970,
#          4L: 1993,
#          5L: 2103,
#          6L: 2142,
#          7L: 2178,
#          8L: 2305,
#          9L: 2105,
#          10L: 2046,
#          11L: 1918,
#          12L: 2110})

# %%
Counter(monthsg)
# Out:
# Counter({1L: 1328,
#          2L: 1131,
#          3L: 1392,
#          4L: 1286,
#          5L: 1365,
#          6L: 1438,
#          7L: 1396,
#          8L: 1465,
#          9L: 1338,
#          10L: 1418,
#          11L: 1384,
#          12L: 1536})

# %%
Counter(monthsh)
# Out:
# Counter({1L: 1029,
#          2L: 920,
#          3L: 1131,
#          4L: 1109,
#          5L: 1224,
#          6L: 1178,
#          7L: 1079,
#          8L: 1235,
#          9L: 1116,
#          10L: 1142,
#          11L: 1064,
#          12L: 1018})

# %%
Counter(monthsa)
# Out:
# Counter({1L: 761,
#          2L: 724,
#          3L: 875,
#          4L: 885,
#          5L: 972,
#          6L: 918,
#          7L: 959,
#          8L: 925,
#          9L: 886,
#          10L: 910,
#          11L: 832,
#          12L: 771})

# %%
Counter(monthsc)
# Out:
# Counter({1L: 828,
#          2L: 745,
#          3L: 833,
#          4L: 1101,
#          5L: 792,
#          6L: 981,
#          7L: 812,
#          8L: 1049,
#          9L: 686,
#          10L: 893,
#          11L: 634,
#          12L: 649})
