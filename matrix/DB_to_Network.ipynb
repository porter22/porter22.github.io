# %% [markdown]
# # Extract data from DB, create Nodelist and Edgelist for D3

# %% [markdown]
# Here we extract feedstocks, processes, outputs and convert them into JSON file that contains nodelist and edgelist for networks

# %% [markdown]
# ### Table of Contents
#
# - [1.Characterisation of Years](#one)
#     - [1.1.Years in the database](#one-one)
#     - [1.2.Capability Matrixes of years](#one-two)
#         - [1.2.1.Getting the labels](#one-two-one)
#         - [1.2.2.Function](#one-two-two)
#     - [1.3.Year profiles](#one-three)
# - [2.Year Correlation Matrix](#two)
#     - [2.1.Considerations](#two-one)
#     - [2.2.Final Year Correlation Matrix](#two-two)
#     - [2.3.Year correlation matrix clustering](#two-three)
# - [3.Correlation of years over time](#three)
# - [4.Research terms over time](#four)
#     - [4.1.Evolution of output terms](#four-one)
#     - [4.2.Evolution of processing technology terms](#four-two)
#     - [4.3.Evolution of feedstock terms](#four-three)
# - [5.Contextual relationships](#five)
#     - [5.1.Oil](#five-one)
#     - [5.2.Sugar](#five-two)
# - [6. Comparing Years](#six)
#     - [6.1.Visualizing the differences](#six-one)
#     - [6.2.Understanding the differences](#six-two)

# %% [markdown]
# Let's start by importing all of the external libraries that will be useful during the analysis.

# %%
# python libraries
from py2neo import Graph
import numpy as np 
from pandas import DataFrame
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import json
import math
import pandas as pd
# import plotly 
# import plotly.graph_objs as go
import qgrid
from scipy import stats, spatial
from sklearn.cluster.bicluster import SpectralBiclustering
import operator
from IPython.display import display, HTML
from matplotlib.colors import ListedColormap


# connection to Neo4j
local_connection_url = "http://localhost:7474/db/data"
connection_to_graph = Graph(local_connection_url, user="neo4j", password="zxc397") 

# plotly credentials
# plotly_config = json.load(open('plotly_config.json'))
# plotly.tools.set_credentials_file(username=plotly_config['username'], api_key=plotly_config['key'])

# %% [markdown]
# ### Total database matrix

# %% [markdown]
# We start by getting all the feedstock, processing technology and output terms. Nodelist is created from these terms.

# %%
f_terms = list(set(DataFrame(connection_to_graph.data('MATCH (a:Asset)-[:CONTAINS]->(fs:Feedstock) RETURN  fs.term, count(a)')).as_matrix()[:, 1]))
o_terms = list(set(DataFrame(connection_to_graph.data('MATCH (a:Asset)-[:CONTAINS]->(fs:Output) RETURN  fs.term, count(a)')).as_matrix()[:, 1]))
pt_terms = list(set(DataFrame(connection_to_graph.data('MATCH (a:Asset)-[:CONTAINS]->(fs:ProcessingTech) RETURN  fs.term, count(a)')).as_matrix()[:, 1]))
bbo = list(f_terms + pt_terms + o_terms)
print 'Number of terms:', len(bbo)
nodes = bbo
print nodes
# Out:
# Number of terms: 352
# [u'vegetable oil', u'recycled ethanol', u'woodwaste/bagasse', u'natural gas', u'various grasses', u'nonedible oils', u'animal fats', u'paper', u'ponderosa pine', u'grass seed', u'sulfite spent liquor from spruce wood pulping', u'osb', u'paper waste', u'corn cob', u'energy grasses', u'logging residues', u'willow', u'crop waste', u'firewood', u'jatropha', u'sugarcane bagasse', u'sugar', u'durum', u'wood', u'municipal solid waste', u'banna grass', u'waste oil', u'cassava pulp', u'barley', u'mixed oilseeds', u'starch', u'white grease', u'coniferous wood', u'corn oil', u'wood waste', u'mixed cellulose', u'corn stalks', u'yellow grease', u'molasses', u'woodchips', u'food waste', u'citrus residues', u'wood chips', u'spent sulphite liquor feedstock', u'palm, rapeseed oil, waste fat', u'cotton residue', u'industrial waste', u'deciduous forests', u'corn stover', u'cereals/sugar', u'waste fat', u'waste vegetable oil', u'tallow', u'sewage', u'white pine', u'hardwood', u'biogas from municipal wastewater treatment facility digesters', u'loblolly pine', u'stump material', u'miscanthus', u'palm', u'milo', u'animal residue', u'bark', u'fall rye', u'agriculture', u'textiles', u'beef tallow', u'animal waste', u'cobs', u'forest residues', u'grass clippings', u'fat products', u'plywood', u'dry biomass', u'southern yellow pine', u'free fatty acid', u'trap grease', u'woody and agricultural by-products', u'syngas from gasifier', u'cellulose', u'wheat', u'organic waste', u'oil plants', u'corn', u'animal manure', u'dung', u'agricultural waste', u'elephant grass', u'soft white spring wheat', u'biogas from landfills', u'mixed grass', u'waste water sludge', u'poppy seed', u'algae', u'rice straw', u'barley straw', u'Giant reed', u'rice hulls', u'canola oil', u'msw', u'digester gas', u'seeds', u'grain', u'distillers grain', u'sugar beet', u'mixed biomass', u'corn stover, cobs', u'brewery waste', u'triticale', u'camelina', u'cellulosic biomass', u'multi feedstock', u'plastics', u'palm stearin', u'poultry fat', u'straw', u'water hyacinth', u'mixedwood', u'hogs', u'beverage waste', u'macroalgae', u'sugar base', u'soy', u'woody biomass', u'maple', u'bagasse', u'wheat straw', u'jathropa', u'medium density fiberboard', u'biodegradable waste', u'corn sugar', u'poplar/energy woods', u'husk', u'fog', u'feed wheat', u'waste', u'soy oil', u'oilseeds', u'pal waste', u'grass straw and corn stalks', u'agricultural biomass', u'glycerin', u'used cooking oil', u'hydrous ethanol', u'seed oil', u'manure', u'shrub willow', u'juncea oil', u'grains', u'syngas', u'barley starch', u'particle board', u'energy crops', u'slash pine', u'lemna', u'lumber', u'hog fuel', u'Decommissioned electricity poles and railway ties', u'agricultural residues', u'grass', u'sorghum', u'virgin oil', u'cps wheat', u'rapeseed oil', u'cooking oil', u'sawdust', u'sugarcane trash', u'radiate pine', u'cheese whey', u'red pine', u'corn/barley', u'switchgrass', u'yard trimmings', u'stover', u'biogenic waste oils', u'douglas fir', u'bagasse/cane trash', u'crude glycerine', u'brown grease', u'waste water', u'garden waste', u'wood processing residues', u'yeast', u'oak', u'pine', u'natural fats', u'forestry', u'wood fuel', u'rice straw, corn stalks', u'steel waste gas (co)', u'mixed prairie grass', u'whey', u'lignocellulosics', u'cellulosic sugars', u'juniper', u'mixed biomass, natural gas', u'sugarcane', u'urban wood', u'flaxseed oil', u'residues', u'cotton gin trash', u'rapeseed', u'arundo donax', u'dedicated energy crops', u'black liquor', u'eucalyptus', u'corn/milo', u'beets', u'non-food grade canola oil', u'non-cellulosic portions of sfw', u'refined vegetable oil', u'vegetable waste', u'poplar', u'palm oil', u'blend', u'hybrid poplar', u'hydrochloric acid', u'algae transesterification', u' aerobic digestion', u'consolidated bioprocessing', u'methane recovery', u'hydroprocessing', u'solar conversion', u'biomass combustion', u'gasification', u'enzymatic hydrolysis', u'biogas productions', u'chemprocessing', u' ...

# %% [markdown]
# ## Convert Neo4j queries to dataframes

# %%
# feedproc = connection_to_graph.data('MATCH p2=(feed:Feedstock)<-[:CONTAINS]-(n:Asset)-[:CONTAINS]->(proc:ProcessingTech) WHERE n.owner = "MONSANTO TECHNOLOGY LLC" RETURN n.id, n.year, feed.term, proc.term LIMIT 500')
feedproc = connection_to_graph.data('MATCH p2=(feed:Feedstock)<-[:CONTAINS]-(n:Asset)-[:CONTAINS]->(proc:ProcessingTech) RETURN n.id, n.year, feed.term, proc.term')
feedout = connection_to_graph.data('MATCH p2=(feed:Feedstock)<-[:CONTAINS]-(n:Asset)-[:CONTAINS]->(out:Output) RETURN n.id, n.year, feed.term, out.term')
procout = connection_to_graph.data('MATCH p2=(proc:ProcessingTech)<-[:CONTAINS]-(n:Asset)-[:CONTAINS]->(out:Output) RETURN n.id, n.year, proc.term, out.term')
df1 = pd.DataFrame(feedproc)
df2 = pd.DataFrame(feedout)
df3 = pd.DataFrame(procout)
df1.count()
# Out:
# feed.term    26376
# n.id         26376
# n.year       26376
# proc.term    26376
# dtype: int64

# %%
df2
# Out:
#         feed.term        n.id n.year     out.term
# 0        plastics  201700567P   2017    biodiesel
# 1   vegetable oil  201700567P   2017    biodiesel
# 2           blend  201700567P   2017    biodiesel
# 3           seeds  201700567P   2017    biodiesel
# 4           grain  201700567P   2017    biodiesel
# 5     cooking oil  201700567P   2017    biodiesel
# 6      canola oil  201700567P   2017    biodiesel
# 7        plastics  201700567M   2017    biodiesel
# 8   vegetable oil  201700567M   2017    biodiesel
# 9           blend  201700567M   2017    biodiesel
# 10          seeds  201700567M   2017    biodiesel
# 11          grain  201700567M   2017    biodiesel
# 12    cooking oil  201700567M   2017    biodiesel
# 13     canola oil  201700567M   2017    biodiesel
# 14       plastics  201700567L   2017    biodiesel
# 15  vegetable oil  201700567L   2017    biodiesel
# 16          blend  201700567L   2017    biodiesel
# 17          seeds  201700567L   2017    biodiesel
# 18          grain  201700567L   2017    biodiesel
# 19    cooking oil  201700567L   2017    biodiesel
# 20     canola oil  201700567L   2017    biodiesel
# 21       plastics  201700567K   2017    biodiesel
# 22  vegetable oil  201700567K   2017    biodiesel
# 23          blend  201700567K   2017    biodiesel
# 24          seeds  201700567K   2017    biodiesel
# 25          grain  201700567K   2017    biodiesel
# 26    cooking oil  201700567K   2017    biodiesel
# 27     canola oil  201700567K   2017    biodiesel
# 28       plastics  201700567R   2017    biodiesel
# 29  vegetable oil  201700567R   2017    biodiesel
# ..            ...         ...    ...          ...
# 33    cooking oil  201700567R   2017    biodiesel
# 34     canola oil  201700567R   2017    biodiesel
# 35       plastics  201700567Q   2017    biodiesel
# 36  vegetable oil  201700567Q   2017    biodiesel
# 37          blend  201700567Q   2017    biodiesel
# 38          seeds  201700567Q   2017    biodiesel
# 39          grain  201700567Q   2017    biodiesel
# 40    cooking oil  201700567Q   2017    biodiesel
# 41     canola oil  201700567Q   2017    biodiesel
# 42         starch  2009K28454   2009  biopolymers
# 43           corn  201668219X   2016  biopolymers
# 44          seeds  201668219X   2016  biopolymers
# 45      sugarcane  201505847F   2015  biopolymers
# 46          sugar  201505847F   2015  biopolymers
# 47           corn  201505847F   2015  biopolymers
# 48            soy  201505847F   2015  biopolymers
# 49        sorghum  201505847F   2015  biopolymers
# 50         starch  201505847F   2015  biopolymers
# 51          grass  201505847F   2015  biopolymers
# 52         barley  201505847F   2015  biopolymers
# 53          wheat  201505847F   2015  biopolymers
# 54      sugarcane  2010N43726   2010  biopolymers
# 55          sugar  2010N43726   2010  biopolymers
# 56           corn  2010N43726   2010  biopolymers
# 57            soy  2010N43726   2010  biopolymers
# 58        sorghum  2010N43726   2010  biopolymers
# 59         starch  2010N43726   2010  biopolymers
# 60          grass  2010N43726   2010  biopolymers
# 61         barley  2010N43726   2010  biopolymers
# 62          wheat  2010N43726   2010  biopolymers
#
# [63 rows x 4 columns]

# %%
df3
# Out:
#          n.id n.year     out.term proc.term
# 0  201700567K   2017    biodiesel  solvents
# 1  201700567L   2017    biodiesel  solvents
# 2  201700567R   2017    biodiesel  solvents
# 3  201700567Q   2017    biodiesel  solvents
# 4  201700567P   2017    biodiesel  solvents
# 5  201700567M   2017    biodiesel  solvents
# 6  2009K28454   2009  biopolymers  pressing

# %% [markdown]
# prepare dataframes for edgelists

# %%
df1.groupby([u'feed.term']).count()
# Out:
#                n.id  n.year  proc.term
# feed.term
# blend             7       7          7
# canola oil        7       7          7
# cooking oil       8       8          8
# grain             7       7          7
# paper             1       1          1
# plastics          7       7          7
# seeds             8       8          8
# starch            2       2          2
# vegetable oil     7       7          7

# %%
print "EDGELIST"
edgelist = []
for index, row in df1.iterrows():
    rowstr = row[u'feed.term'] + "," + row[u'proc.term']
    #edgelist = edgelist + str
    edgelist.append(rowstr)
# print "df2-------------"
for index, row in df2.iterrows():
    rowstr = row[u'feed.term'] + "," + row[u'out.term']
    edgelist.append(rowstr)
    #edgelist = edgelist + str
# print "df3-------------"
for index, row in df3.iterrows():
    rowstr = row[u'proc.term'] + "," + row[u'out.term']
    edgelist.append(rowstr)
    #edgelist = edgelist + str
print edgelist
# Out:
# EDGELIST
# [u'cooking oil,solvents', u'waste,solvents', u'waste,solvents', u'industrial waste,solvents', u'free fatty acid,solvents', u'corn stover,solvents', u'stover,solvents', u'sugar,solvents', u'corn,solvents', u'cellulose,solvents', u'cellulosic biomass,solvents', u'cellulose,solvents', u'douglas fir,solvents', u'wood,solvents', u'woody biomass,solvents', u'cellulose,solvents', u'pine,solvents', u'wood,solvents', u'sawdust,solvents', u'waste water,solvents', u'algae,solvents', u'waste,solvents', u'waste water,solvents', u'palm,solvents', u'waste,solvents', u'sewage,solvents', u'vegetable oil,solvents', u'cooking oil,solvents', u'waste,solvents', u'waste,solvents', u'waste water,solvents', u'algae,solvents', u'pal waste,solvents', u'waste,solvents', u'sewage,solvents', u'algae,solvents', u'vegetable oil,solvents', u'soy,solvents', u'algae,solvents', u'cellulose,solvents', u'cellulosic biomass,solvents', u'sugar,solvents', u'cellulose,solvents', u'hybrid poplar,solvents', u'poplar,solvents', u'residues,solvents', u'sugar,solvents', u'cellulose,solvents', u'cellulosic biomass,solvents', u'rice straw,solvents', u'straw,solvents', u'algae,solvents', u'vegetable oil,solvents', u'seed oil,solvents', u'algae,solvents', u'algae,solvents', u'residues,solvents', u'vegetable oil,solvents', u'seed oil,solvents', u'seeds,solvents', u'oilseeds,solvents', u'algae,solvents', u'paper,solvents', u'sugar,solvents', u'cellulose,solvents', u'pine,solvents', u'wood,solvents', u'grass,solvents', u'bark,solvents', u'algae,solvents', u'algae,solvents', u'macroalgae,solvents', u'free fatty acid,solvents', u'sugar,solvents', u'cellulose,solvents', u'palm oil,solvents', u'agricultural waste,solvents', u'palm,solvents', u'waste,solvents', u'algae,solvents', u'vegetable oil,solvents', u'seed oil,solvents', u'rapeseed,solvents', u'rapeseed oil,solvents', u'sugarcane,solvents', u'bagasse,solvents', u'sugarcane bagasse,solvents', u'sugar,solvents', u'cellulose,solvents', u'residues,solvents', u'cellulosic biomass,solvents', u'algae,solvents', u'paper,solvents', u'sugar,solvents', u'cellulose,solvents', u'switchgrass,solvents', u'grass,solvents', u'cellulose,solvents', u'water hyacinth,solvents', u'waste water,solvents', u'cellulose,solvents', u'wood,solvents', u'waste,solvents', u'sewage,solvents', u'corn stover,solvents', u'stover,solvents', u'corn,solvents', u'sugar,solvents', u'cellulosic biomass,solvents', u'vegetable oil,solvents', u'soy,solvents', u'free fatty acid,solvents', u'corn,solvents', u'vegetable oil,solvents', u'seed oil,solvents', u'palm oil,solvents', u'palm,solvents', u'corn oil,solvents', u'cellulose,solvents', u'waste,solvents', u'free fatty acid,solvents', u'algae,solvents', u'waste water,solvents', u'waste,solvents', u'sewage,solvents', u'waste water,solvents', u'fog,solvents', u'cooking oil,solvents', u'waste,solvents', u'sewage,solvents', u'free fatty acid,solvents', u'syngas,solvents', u'pal waste,solvents', u'wood,solvents', u'energy crops,solvents', u'waste,solvents', u'agriculture,solvents', u'jatropha,solvents', u'palm,solvents', u'yeast,solvents', u'dry biomass,solvents', u'vegetable oil,solvents', u'yeast,solvents', u'animal fats,solvents', u'corn stover,solvents', u'stover,solvents', u'corn,solvents', u'grain,solvents', u'energy crops,solvents', u'algae,solvents', u'palm oil,solvents', u'palm,solvents', u'soy,solvents', u'cellulosic biomass,solvents', u'algae,solvents', u'paper,solvents', u'corn stover,solvents', u'stover,solvents', u'sugar,solvents', u'corn,solvents', u'cellulose,solvents', u'paper,solvents', u'vegetable oil,solvents', u'waste oil,solvents', u'waste,solvents', u'blend,solvents', u'sugar,solvents', u'paper,solvents', u'palm,solvents', u'yeast,solvents', u'sawdust,solvents', u'sawdust,solvents', u'cellulose,solvents', u'cellulose,solvents', u'sugarcane,solvents', u'bagasse,solvents', u'sugar,solvents', u'cellulose,solvents', u'eucalyptus,solvents', u'straw,solvents', u'willow,solvents', u'pine,solvents', u'sorghum,so ...

# %% [markdown]
# ## Prepare Nodelist for JSON file structure

# %%
strjson = '{"nodes":['
for node in nodes:
    #print node
    strjson = strjson + '{"name":"' + node + '","group":1},'

#remove last comma from json
strjson = strjson[:-1]
print strjson
# Out:
# {"nodes":[{"name":"vegetable oil","group":1},{"name":"recycled ethanol","group":1},{"name":"woodwaste/bagasse","group":1},{"name":"natural gas","group":1},{"name":"various grasses","group":1},{"name":"nonedible oils","group":1},{"name":"animal fats","group":1},{"name":"paper","group":1},{"name":"ponderosa pine","group":1},{"name":"grass seed","group":1},{"name":"sulfite spent liquor from spruce wood pulping","group":1},{"name":"osb","group":1},{"name":"paper waste","group":1},{"name":"corn cob","group":1},{"name":"energy grasses","group":1},{"name":"logging residues","group":1},{"name":"willow","group":1},{"name":"crop waste","group":1},{"name":"firewood","group":1},{"name":"jatropha","group":1},{"name":"sugarcane bagasse","group":1},{"name":"sugar","group":1},{"name":"durum","group":1},{"name":"wood","group":1},{"name":"municipal solid waste","group":1},{"name":"banna grass","group":1},{"name":"waste oil","group":1},{"name":"cassava pulp","group":1},{"name":"barley","group":1},{"name":"mixed oilseeds","group":1},{"name":"starch","group":1},{"name":"white grease","group":1},{"name":"coniferous wood","group":1},{"name":"corn oil","group":1},{"name":"wood waste","group":1},{"name":"mixed cellulose","group":1},{"name":"corn stalks","group":1},{"name":"yellow grease","group":1},{"name":"molasses","group":1},{"name":"woodchips","group":1},{"name":"food waste","group":1},{"name":"citrus residues","group":1},{"name":"wood chips","group":1},{"name":"spent sulphite liquor feedstock","group":1},{"name":"palm, rapeseed oil, waste fat","group":1},{"name":"cotton residue","group":1},{"name":"industrial waste","group":1},{"name":"deciduous forests","group":1},{"name":"corn stover","group":1},{"name":"cereals/sugar","group":1},{"name":"waste fat","group":1},{"name":"waste vegetable oil","group":1},{"name":"tallow","group":1},{"name":"sewage","group":1},{"name":"white pine","group":1},{"name":"hardwood","group":1},{"name":"biogas from municipal wastewater treatment facility digesters","group":1},{"name":"loblolly pine","group":1},{"name":"stump material","group":1},{"name":"miscanthus","group":1},{"name":"palm","group":1},{"name":"milo","group":1},{"name":"animal residue","group":1},{"name":"bark","group":1},{"name":"fall rye","group":1},{"name":"agriculture","group":1},{"name":"textiles","group":1},{"name":"beef tallow","group":1},{"name":"animal waste","group":1},{"name":"cobs","group":1},{"name":"forest residues","group":1},{"name":"grass clippings","group":1},{"name":"fat products","group":1},{"name":"plywood","group":1},{"name":"dry biomass","group":1},{"name":"southern yellow pine","group":1},{"name":"free fatty acid","group":1},{"name":"trap grease","group":1},{"name":"woody and agricultural by-products","group":1},{"name":"syngas from gasifier","group":1},{"name":"cellulose","group":1},{"name":"wheat","group":1},{"name":"organic waste","group":1},{"name":"oil plants","group":1},{"name":"corn","group":1},{"name":"animal manure","group":1},{"name":"dung","group":1},{"name":"agricultural waste","group":1},{"name":"elephant grass","group":1},{"name":"soft white spring wheat","group":1},{"name":"biogas from landfills","group":1},{"name":"mixed grass","group":1},{"name":"waste water sludge","group":1},{"name":"poppy seed","group":1},{"name":"algae","group":1},{"name":"rice straw","group":1},{"name":"barley straw","group":1},{"name":"Giant reed","group":1},{"name":"rice hulls","group":1},{"name":"canola oil","group":1},{"name":"msw","group":1},{"name":"digester gas","group":1},{"name":"seeds","group":1},{"name":"grain","group":1},{"name":"distillers grain","group":1},{"name":"sugar beet","group":1},{"name":"mixed biomass","group":1},{"name":"corn stover, cobs","group":1},{"name":"brewery waste","group":1},{"name":"triticale","group":1},{"name":"camelina","group":1},{"name":"cellulosic biomass","group":1},{"name":"multi feedstock","group":1},{"name":"plastics","group":1},{"name":"palm stearin","group":1},{"name":"poultry fat","group":1},{"nam ...

# %%
edgelist
# Out:
# [u'cooking oil,solvents',
#  u'waste,solvents',
#  u'waste,solvents',
#  u'industrial waste,solvents',
#  u'free fatty acid,solvents',
#  u'corn stover,solvents',
#  u'stover,solvents',
#  u'sugar,solvents',
#  u'corn,solvents',
#  u'cellulose,solvents',
#  u'cellulosic biomass,solvents',
#  u'cellulose,solvents',
#  u'douglas fir,solvents',
#  u'wood,solvents',
#  u'woody biomass,solvents',
#  u'cellulose,solvents',
#  u'pine,solvents',
#  u'wood,solvents',
#  u'sawdust,solvents',
#  u'waste water,solvents',
#  u'algae,solvents',
#  u'waste,solvents',
#  u'waste water,solvents',
#  u'palm,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'vegetable oil,solvents',
#  u'cooking oil,solvents',
#  u'waste,solvents',
#  u'waste,solvents',
#  u'waste water,solvents',
#  u'algae,solvents',
#  u'pal waste,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'algae,solvents',
#  u'vegetable oil,solvents',
#  u'soy,solvents',
#  u'algae,solvents',
#  u'cellulose,solvents',
#  u'cellulosic biomass,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'hybrid poplar,solvents',
#  u'poplar,solvents',
#  u'residues,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'cellulosic biomass,solvents',
#  u'rice straw,solvents',
#  u'straw,solvents',
#  u'algae,solvents',
#  u'vegetable oil,solvents',
#  u'seed oil,solvents',
#  u'algae,solvents',
#  u'algae,solvents',
#  u'residues,solvents',
#  u'vegetable oil,solvents',
#  u'seed oil,solvents',
#  u'seeds,solvents',
#  u'oilseeds,solvents',
#  u'algae,solvents',
#  u'paper,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'pine,solvents',
#  u'wood,solvents',
#  u'grass,solvents',
#  u'bark,solvents',
#  u'algae,solvents',
#  u'algae,solvents',
#  u'macroalgae,solvents',
#  u'free fatty acid,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'palm oil,solvents',
#  u'agricultural waste,solvents',
#  u'palm,solvents',
#  u'waste,solvents',
#  u'algae,solvents',
#  u'vegetable oil,solvents',
#  u'seed oil,solvents',
#  u'rapeseed,solvents',
#  u'rapeseed oil,solvents',
#  u'sugarcane,solvents',
#  u'bagasse,solvents',
#  u'sugarcane bagasse,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'residues,solvents',
#  u'cellulosic biomass,solvents',
#  u'algae,solvents',
#  u'paper,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'switchgrass,solvents',
#  u'grass,solvents',
#  u'cellulose,solvents',
#  u'water hyacinth,solvents',
#  u'waste water,solvents',
#  u'cellulose,solvents',
#  u'wood,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'corn stover,solvents',
#  u'stover,solvents',
#  u'corn,solvents',
#  u'sugar,solvents',
#  u'cellulosic biomass,solvents',
#  u'vegetable oil,solvents',
#  u'soy,solvents',
#  u'free fatty acid,solvents',
#  u'corn,solvents',
#  u'vegetable oil,solvents',
#  u'seed oil,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'corn oil,solvents',
#  u'cellulose,solvents',
#  u'waste,solvents',
#  u'free fatty acid,solvents',
#  u'algae,solvents',
#  u'waste water,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'waste water,solvents',
#  u'fog,solvents',
#  u'cooking oil,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'free fatty acid,solvents',
#  u'syngas,solvents',
#  u'pal waste,solvents',
#  u'wood,solvents',
#  u'energy crops,solvents',
#  u'waste,solvents',
#  u'agriculture,solvents',
#  u'jatropha,solvents',
#  u'palm,solvents',
#  u'yeast,solvents',
#  u'dry biomass,solvents',
#  u'vegetable oil,solvents',
#  u'yeast,solvents',
#  u'animal fats,solvents',
#  u'corn stover,solvents',
#  u'stover,solvents',
#  u'corn,solvents',
#  u'grain,solvents',
#  u'energy crops,solvents',
#  u'algae,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'soy,solvents',
#  u'cellulosic biomass,solvents',
#  u'algae,solvents',
#  u'paper,solvents',
#  u'corn stover,solvents',
#  u'stover,solvents',
#  u'sugar,solvents',
#  u'corn,solvents',
#  u'cellulose,solvents',
#  u'paper,solvents',
#  u'vegetable oil,solvents',
#  u'waste oil,solvents',
#  u'waste,solvents',
#  u'blend,solvents',
#  u'sugar,solvents',
#  u'paper,solvents',
#  u'palm,solvents',
#  u'yeast,solvents',
#  u'sawdust,solvents',
#  u'sawdust,solvents',
#  u'cellulose,solvents',
#  u'cellulose,solvents',
#  u'sugarcane,solvents',
#  u'bagasse,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'eucalyptus,solvents',
#  u'straw,solvents',
#  u'willow,solvents',
#  u'pine,solvents',
#  u'sorghum,solvents',
#  u'wood,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'cellulosic biomass,solvents',
#  u'wheat,solvents',
#  u'waste,solvents',
#  u'industrial waste,solvents',
#  u'free fatty acid,solvents',
#  u'sugarcane,solvents',
#  u'bagasse,solvents',
#  u'sugarcane bagasse,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'cooking oil,solvents',
#  u'waste,solvents',
#  u'vegetable oil,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'waste water,solvents',
#  u'sugar,solvents',
#  u'wood waste,solvents',
#  u'pine,solvents',
#  u'wood,solvents',
#  u'waste,solvents',
#  u'algae,solvents',
#  u'dry biomass,solvents',
#  u'algae,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'sewage,solvents',
#  u'free fatty acid,solvents',
#  u'soy,solvents',
#  u'organic waste,solvents',
#  u'natural gas,solvents',
#  u'paper,solvents',
#  u'waste,solvents',
#  u'sorghum,solvents',
#  u'wheat,solvents',
#  u'algae,solvents',
#  u'vegetable oil,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'waste,solvents',
#  u'algae,solvents',
#  u'cooking oil,solvents',
#  u'waste,solvents',
#  u'waste water,solvents',
#  u'vegetable oil,solvents',
#  u'waste,solvents',
#  u'glycerin,solvents',
#  u'free fatty acid,solvents',
#  u'vegetable oil,solvents',
#  u'jatropha,solvents',
#  u'free fatty acid,solvents',
#  u'wood,solvents',
#  u'waste,solvents',
#  u'woody biomass,solvents',
#  u'industrial waste,solvents',
#  u'sawdust,solvents',
#  u'algae,solvents',
#  u'palm,solvents',
#  u'algae,solvents',
#  u'palm,solvents',
#  u'cellulose,solvents',
#  u'hydrous ethanol,solvents',
#  u'food waste,solvents',
#  u'plastics,solvents',
#  u'syngas,solvents',
#  u'cellulose,solvents',
#  u'residues,solvents',
#  u'waste,solvents',
#  u'algae,solvents',
#  u'bagasse,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'switchgrass,solvents',
#  u'grass,solvents',
#  u'vegetable oil,solvents',
#  u'canola oil,solvents',
#  u'cellulose,solvents',
#  u'wood,solvents',
#  u'wood chips,solvents',
#  u'residues,solvents',
#  u'cellulosic biomass,solvents',
#  u'bark,solvents',
#  u'woody biomass,solvents',
#  u'sawdust,solvents',
#  u'algae,solvents',
#  u'pal waste,solvents',
#  u'palm,solvents',
#  u'waste,solvents',
#  u'municipal solid waste,solvents',
#  u'sugar,solvents',
#  u'vegetable oil,solvents',
#  u'cellulose,solvents',
#  u'straw,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'waste water,solvents',
#  u'pal waste,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'algae,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'seeds,solvents',
#  u'waste,solvents',
#  u'paper,solvents',
#  u'blend,solvents',
#  u'algae,solvents',
#  u'paper,solvents',
#  u'wood,solvents',
#  u'woody biomass,solvents',
#  u'algae,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'wood,solvents',
#  u'bagasse,solvents',
#  u'wheat straw,solvents',
#  u'rice straw,solvents',
#  u'miscanthus,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'paper,solvents',
#  u'straw,solvents',
#  u'poplar,solvents',
#  u'cellulosic biomass,solvents',
#  u'waste,solvents',
#  u'wheat,solvents',
#  u'vegetable oil,solvents',
#  u'waste,solvents',
#  u'industrial waste,solvents',
#  u'animal fats,solvents',
#  u'vegetable oil,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'algae,solvents',
#  u'cellulose,solvents',
#  u'vegetable oil,solvents',
#  u'seed oil,solvents',
#  u'seeds,solvents',
#  u'rapeseed,solvents',
#  u'canola oil,solvents',
#  u'yeast,solvents',
#  u'rapeseed oil,solvents',
#  u'oilseeds,solvents',
#  u'soy,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'starch,solvents',
#  u'residues,solvents',
#  u'wheat,solvents',
#  u'cellulose,solvents',
#  u'sorghum,solvents',
#  u'grain,solvents',
#  u'grains,solvents',
#  u'rice straw,solvents',
#  u'paper,solvents',
#  u'straw,solvents',
#  u'algae,solvents',
#  u'algae,solvents',
#  u'dry biomass,solvents',
#  u'pal waste,solvents',
#  u'waste,solvents',
#  u'municipal solid waste,solvents',
#  u'waste water,solvents',
#  u'palm,solvents',
#  u'waste,solvents',
#  u'sewage,solvents',
#  u'switchgrass,solvents',
#  u'grass,solvents',
#  u'energy crops,solvents',
#  u'agriculture,solvents',
#  u'cellulose,solvents',
#  u'algae,solvents',
#  u'paper,solvents',
#  u'palm,solvents',
#  u'dry biomass,solvents',
#  u'corn,solvents',
#  u'sugar,solvents',
#  u'corn cob,solvents',
#  u'husk,solvents',
#  u'sewage,solvents',
#  u'paper,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'vegetable oil,solvents',
#  u'waste,solvents',
#  u'cellulose,solvents',
#  u'loblolly pine,solvents',
#  u'pine,solvents',
#  u'wood,solvents',
#  u'sugar,solvents',
#  u'yeast,solvents',
#  u'cellulose,solvents',
#  u'cellulosic biomass,solvents',
#  u'seeds,solvents',
#  u'vegetable oil,solvents',
#  u'cellulose,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'straw,solvents',
#  u'waste,solvents',
#  u'cellulosic biomass,solvents',
#  u'triticale,solvents',
#  u'residues,solvents',
#  u'sugarcane,solvents',
#  u'bagasse,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'residues,solvents',
#  u'paper,solvents',
#  u'sugar,solvents',
#  u'paper,solvents',
#  u'yeast,solvents',
#  u'yeast,solvents',
#  u'vegetable oil,solvents',
#  u'yeast,solvents',
#  u'plastics,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'paper,solvents',
#  u'maple,solvents',
#  u'hardwood,solvents',
#  u'wood,solvents',
#  u'wood fuel,solvents',
#  u'algae,solvents',
#  u'waste water,solvents',
#  u'algae,solvents',
#  u'palm,solvents',
#  u'waste,solvents',
#  u'algae,solvents',
#  u'algae,solvents',
#  u'algae,solvents',
#  u'corn,solvents',
#  u'wheat straw,solvents',
#  u'straw,solvents',
#  u'cellulose,solvents',
#  u'paper,solvents',
#  u'wheat,solvents',
#  u'algae,solvents',
#  u'palm,solvents',
#  u'algae,solvents',
#  u'paper,solvents',
#  u'algae,solvents',
#  u'algae,solvents',
#  u'miscanthus,solvents',
#  u'algae,solvents',
#  u'dry biomass,solvents',
#  u'algae,solvents',
#  u'waste,solvents',
#  u'agriculture,solvents',
#  u'sewage,solvents',
#  u'corn stover,solvents',
#  u'waste water,solvents',
#  u'stover,solvents',
#  u'corn,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'yeast,solvents',
#  u'waste,solvents',
#  u'cellulosic biomass,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'grass,solvents',
#  u'algae,solvents',
#  u'palm,solvents',
#  u'algae,solvents',
#  u'vegetable oil,solvents',
#  u'yeast,solvents',
#  u'algae,solvents',
#  u'free fatty acid,solvents',
#  u'rice straw,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'straw,solvents',
#  u'cellulosic biomass,solvents',
#  u'cellulose,solvents',
#  u'waste,solvents',
#  u'residues,solvents',
#  u'cellulosic biomass,solvents',
#  u'sugar,solvents',
#  u'yeast,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'algae,solvents',
#  u'whey,solvents',
#  u'cheese whey,solvents',
#  u'agricultural waste,solvents',
#  u'waste,solvents',
#  u'sugarcane,solvents',
#  u'bagasse,solvents',
#  u'sugarcane bagasse,solvents',
#  u'sugar,solvents',
#  u'black liquor,solvents',
#  u'algae,solvents',
#  u'agricultural waste,solvents',
#  u'yeast,solvents',
#  u'waste,solvents',
#  u'sugar,solvents',
#  u'pal waste,solvents',
#  u'paper,solvents',
#  u'waste,solvents',
#  u'municipal solid waste,solvents',
#  u'forest residues,solvents',
#  u'cellulose,solvents',
#  u'waste,solvents',
#  u'residues,solvents',
#  u'forestry,solvents',
#  u'vegetable oil,solvents',
#  u'paper,solvents',
#  u'palm oil,solvents',
#  u'palm,solvents',
#  u'residues,solvents',
#  u'seeds,solvents',
#  u'algae,solvents',
#  u'sugar,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'wood,solvents',
#  u'wood chips,solvents',
#  u'woody biomass,solvents',
#  u'cellulose,solvents',
#  u'plastics,solvents',
#  u'syngas,solvents',
#  u'vegetable oil,solvents',
#  u'waste,solvents',
#  u'plastics,solvents',
#  u'sugar,solvents',
#  u'yeast,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'sugar,solvents',
#  u'paper,solvents',
#  u'sugar,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'blend,solvents',
#  u'plastics,solvents',
#  u'textiles,solvents',
#  u'palm,solvents',
#  u'sugar,solvents',
#  u'vegetable oil,solvents',
#  u'algae,solvents',
#  u'cellulose,solvents',
#  u'sugar,solvents',
#  u'syngas,solvents',
#  u'blend,solvents',
#  u'palm,solvents',
#  u'yeast,solvents',
#  u'sugar beet,solvents',
#  u'bagasse,solvents',
#  u'rice straw,solvents',
#  u'barley straw,solvents',
#  u'wheat straw,solvents',
#  u'urban wood,solvents',
#  u'rice hulls,solvents',
#  u'sugar,solvents',
#  u'corn,solvents',
#  u'wood waste,solvents',
#  u'pal waste,solvents',
#  u'straw,solvents',
#  u'corn cob,solvents',
#  u'animal waste,solvents',
#  u'hardwood,solvents',
#  u'soy,solvents',
#  u'poplar,solvents',
#  u'pine,solvents',
#  u'wood,solvents',
#  u'waste,solvents',
#  u'grass,solvents',
#  u'barley,solvents',
#  u'corn stalks,solvents',
#  u'cobs,solvents',
#  u'husk,solvents',
#  u'industrial waste,solvents',
#  u'wheat,solvents',
#  u'plastics,solvents',
#  u'sugar,solvents',
#  u'yeast,solvents',
#  u'textiles,solvents',
#  u'cellulose,solvents',
#  u'wood,solvents',
#  u'residues,solvents',
#  u'waste,solvents',
#  u'plastics,solvents',
#  u'yeast,solvents',
#  u'blend,solvents',
#  u'blend,solvents',
#  u'bagasse,solvents',
#  u'stover,solvents',
#  u'sugar,solvents',
#  u'miscanthus,solvents',
#  u'cellulose,solvents',
#  u'straw,solvents',
#  u'paper,solvents',
#  u'blend,solvents',
#  u'sorghum,solvents',
#  u'wood,solvents',
#  u'waste,solvents',
#  u'agricultural residues,solvents',
#  u'grass,solvents',
#  u'cellulosic biomass,solvents',
#  u'residues,solvents',
#  u'municipal solid waste,solvents',
#  u'forestry,solvents',
#  u'algae,solvents',
#  u'cellulose,solvents',
#  u'paper,solvents',
#  u'waste,solvents',
#  u'cellulosic biomass,solvents',
#  u'residues,solvents',
#  u'forestry,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'blend,solvents',
#  u'grass,solvents',
#  u'energy crops,solvents',
#  u'cellulosic biomass,solvents',
#  u'cellulose,solvents',
#  u'waste,solvents',
#  u'textiles,solvents',
#  u'molasses,solvents',
#  u'waste,solvents',
#  u'residues,solvents',
#  u'agriculture,solvents',
#  u'manure,solvents',
#  u'sugarcane,solvents',
#  u'bagasse,solvents',
#  u'rice straw,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'straw,solvents',
#  u'eucalyptus,solvents',
#  u'pine,solvents',
#  u'grass,solvents',
#  u'cellulosic biomass,solvents',
#  u'wheat,solvents',
#  u'jatropha,solvents',
#  u'seeds,solvents',
#  u'particle board,solvents',
#  u'algae,solvents',
#  u'corn,solvents',
#  u'starch,solvents',
#  u'soy,solvents',
#  u'algae,solvents',
#  u'wood,solvents',
#  u'vegetable oil,solvents',
#  u'seed oil,solvents',
#  u'yeast,solvents',
#  u'algae,solvents',
#  u'soy,solvents',
#  u'free fatty acid,solvents',
#  u'algae,solvents',
#  u'residues,solvents',
#  u'seeds,solvents',
#  u'sugarcane,solvents',
#  u'bagasse,solvents',
#  u'sugarcane bagasse,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'vegetable oil,solvents',
#  u'seed oil,solvents',
#  u'cooking oil,solvents',
#  u'waste,solvents',
#  u'vegetable oil,solvents',
#  u'seeds,solvents',
#  u'tallow,solvents',
#  u'forestry,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'cellulosic biomass,solvents',
#  u'cellulosic sugars,solvents',
#  u'organic waste,solvents',
#  u'waste,solvents',
#  u'corn stover,solvents',
#  u'stover,solvents',
#  u'corn,solvents',
#  u'cellulose,solvents',
#  u'cellulosic biomass,solvents',
#  u'residues,solvents',
#  u'corn stover,solvents',
#  u'stover,solvents',
#  u'corn,solvents',
#  u'cellulose,solvents',
#  u'waste,solvents',
#  u'cellulosic biomass,solvents',
#  u'residues,solvents',
#  u'seeds,solvents',
#  u'tallow,solvents',
#  u'forestry,solvents',
#  u'cellulose,solvents',
#  u'algae,solvents',
#  u'corn,solvents',
#  u'pine,solvents',
#  u'yeast,solvents',
#  u'corn oil,solvents',
#  u'waste,solvents',
#  u'plastics,solvents',
#  u'vegetable oil,solvents',
#  u'blend,solvents',
#  u'seeds,solvents',
#  u'grain,solvents',
#  u'cooking oil,solvents',
#  u'canola oil,solvents',
#  u'plastics,solvents',
#  u'vegetable oil,solvents',
#  u'blend,solvents',
#  u'seeds,solvents',
#  u'grain,solvents',
#  u'cooking oil,solvents',
#  u'canola oil,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'straw,solvents',
#  u'wood,solvents',
#  u'yeast,solvents',
#  u'cellulose,solvents',
#  u'vegetable oil,solvents',
#  u'soy,solvents',
#  u'palm,solvents',
#  u'glycerin,solvents',
#  u'animal fats,solvents',
#  u'cellulose,solvents',
#  u'cellulosic biomass,solvents',
#  u'vegetable oil,solvents',
#  u'waste,solvents',
#  u'industrial waste,solvents',
#  u'plastics,solvents',
#  u'algae,solvents',
#  u'cellulose,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'yeast,solvents',
#  u'plastics,solvents',
#  u'vegetable oil,solvents',
#  u'blend,solvents',
#  u'seeds,solvents',
#  u'grain,solvents',
#  u'cooking oil,solvents',
#  u'canola oil,solvents',
#  u'plastics,solvents',
#  u'vegetable oil,solvents',
#  u'blend,solvents',
#  u'seeds,solvents',
#  u'grain,solvents',
#  u'cooking oil,solvents',
#  u'canola oil,solvents',
#  u'plastics,solvents',
#  u'vegetable oil,solvents',
#  u'blend,solvents',
#  u'seeds,solvents',
#  u'grain,solvents',
#  u'cooking oil,solvents',
#  u'canola oil,solvents',
#  u'plastics,solvents',
#  u'vegetable oil,solvents',
#  u'blend,solvents',
#  u'seeds,solvents',
#  u'grain,solvents',
#  u'cooking oil,solvents',
#  u'canola oil,solvents',
#  u'plastics,solvents',
#  u'vegetable oil,solvents',
#  u'blend,solvents',
#  u'seeds,solvents',
#  u'grain,solvents',
#  u'cooking oil,solvents',
#  u'canola oil,solvents',
#  u'sugar,solvents',
#  u'yeast,solvents',
#  u'algae,solvents',
#  u'cellulose,solvents',
#  u'blend,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'waste oil,solvents',
#  u'waste,solvents',
#  u'glycerin,solvents',
#  u'blend,solvents',
#  u'cellulose,solvents',
#  u'plastics,solvents',
#  u'algae,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'jatropha,solvents',
#  u'waste,solvents',
#  u'plastics,solvents',
#  u'textiles,solvents',
#  u'organic waste,solvents',
#  u'waste,solvents',
#  u'corn,solvents',
#  u'algae,solvents',
#  u'sugar,solvents',
#  u'glycerin,solvents',
#  u'waste,solvents',
#  u'residues,solvents',
#  u'free fatty acid,solvents',
#  u'trap grease,solvents',
#  u'brown grease,solvents',
#  u'natural gas,solvents',
#  u'wood,solvents',
#  u'cellulosic biomass,solvents',
#  u'textiles,solvents',
#  u'cellulose,solvents',
#  u'vegetable oil,solvents',
#  u'palm,solvents',
#  u'glycerin,solvents',
#  u'animal fats,solvents',
#  u'sugar,solvents',
#  u'cellulose,solvents',
#  u'wood,solvents',
#  u'waste,solvents',
#  u'cellulosic biomass,solvents',
#  u'residues,solvents',
#  u'forestry,solvents',
#  u'blend,solvents',
#  u'cellulose,solvents',
#  u'plastics,solvents',
#  u'textiles,solvents',
#  u'algae,solvents',
#  u'cellulose,solvents',
#  u'blend,solvents',
#  u'algae,solvents',
#  u'yeast,solvents',
#  u'algae,solvents',
#  u'algae,solvents',
#  u'blend,solvents',
#  u'cooking oil,solvents',
#  u'waste,solvents',
#  u'used cooking oil,solvents',
#  u'free fatty acid,solvents',
#  u'waste,solvents',
#  u'cellulose,solvents',
#  u'black liquor,solvents',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'whey,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'algae,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'grain,fermentation',
#  u'grain,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugar,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'barley starch,fermentation',
#  u'starch,fermentation',
#  u'barley,fermentation',
#  u'barley starch,fermentation',
#  u'starch,fermentation',
#  u'barley,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'corn/milo,fermentation',
#  u'milo,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'rapeseed,fermentation',
#  u'starch,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'corn,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'cellulose,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'starch,fermentation',
#  u'sugarcane,fermentation',
#  u'bagasse,fermentation',
#  u'sugarcane bagasse,fermentation',
#  u'sugar,fermentation',
#  u'straw,fermentation',
#  u'wood,fermentation',
#  u'lignocellulosics,fermentation',
#  u'energy crops,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'starch,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'starch,fermentation',
#  u'food waste,fermentation',
#  u'msw,fermentation',
#  u'sugar,fermentation',
#  u'cellulose,fermentation',
#  u'paper,fermentation',
#  u'residues,fermentation',
#  u'waste,fermentation',
#  u'municipal solid waste,fermentation',
#  u'corn stover,fermentation',
#  u'bagasse,fermentation',
#  u'textiles,fermentation',
#  u'stover,fermentation',
#  u'sugar,fermentation',
#  u'natural gas,fermentation',
#  u'corn,fermentation',
#  u'cellulose,fermentation',
#  u'straw,fermentation',
#  u'paper,fermentation',
#  u'agricultural residues,fermentation',
#  u'residues,fermentation',
#  u'barley,fermentation',
#  u'wheat,fermentation',
#  u'sugarcane,fermentation',
#  u'sugar,fermentation',
#  u'cellulose,fermentation',
#  u'yeast,fermentation',
#  u'corn stover,fermentation',
#  u'wheat straw,fermentation',
#  u'stover,fermentation',
#  u'corn,fermentation',
#  u'straw,fermentation',
#  u'agricultural residues,fermentation',
#  u'residues,fermentation',
#  u'grass,fermentation',
#  u'wheat,fermentation',
#  u'agricultural residues,fermentation',
#  u'energy crops,fermentation',
#  u'residues,fermentation',
#  u'waste,fermentation',
#  u'sewage,fermentation',
#  u'municipal solid waste,fermentation',
#  u'manure,fermentation',
#  u'natural gas,fermentation',
#  u'syngas,fermentation',
#  u'corn,fermentation',
#  u'wood,fermentation',
#  u'wood chips,fermentation',
#  u'sugar,fermentation',
#  u'cellulose,fermentation',
#  u'switchgrass,fermentation',
#  u'wood,fermentation',
#  u'yeast,fermentation',
#  u'wood chips,fermentation',
#  u'grass,fermentation',
#  u'cellulose,fermentation',
#  u'eucalyptus,fermentation',
#  u'wood,fermentation',
#  u'yeast,fermentation',
#  u'wood chips,fermentation',
#  u'cellulosic biomass,fermentation',
#  u'straw,fermentation',
#  u'yeast,fermentation',
#  u'yeast,fermentation',
#  u'sugarcane,fermentation',
#  u'corn stover,fermentation',
#  u'bagasse,fermentation',
#  u'sugarcane bagasse,fermentation',
#  u'stover,fermentation',
#  u'sugar,fermentation',
#  u'corn,fermentation',
#  u'forestry,fermentation',
#  ...]

# %% [markdown]
# ## Prepare Edgelist for JSON file structure

# %%
#prepare heading for edgelist
stredges = '],"links":['
for edge in edgelist:
    pair = edge.split(",")
    # use nodes indexes in nodelist for later D3 usage
    # strpair = '{"source":"' + pair[0] + '","target":"' + pair[1] + '","value":1},'
    try:
        b = nodes.index(pair[0])
        c = nodes.index(pair[1])
    except ValueError:
        print "Error: " + pair[0] + pair[1]
    else:
        strpair = '{"source":' + str(nodes.index(pair[0])) + ',"target":' + str(nodes.index(pair[1])) + ',"value":1},'
        # print strpair
        stredges = stredges + strpair
#remove last comma from stredges
stredges = stredges[:-1]
stredges = stredges + "]}"
print stredges
# Out:
# Error: rice straw corn stalks
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: corn stover cobs
# Error: rice straw corn stalks
# Error: corn stover cobs
# Error: mixed biomassmethanol synthesis
# Error: natural gasmethanol synthesis
# Error: mixed biomass natural gas
# Error: mixed biomassmethanol synthesis
# Error: natural gasmethanol synthesis
# Error: mixed biomass natural gas
# Error: mixed biomassmethanol synthesis
# Error: natural gasmethanol synthesis
# Error: mixed biomass natural gas
# Error: rice straw corn stalks
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: rice straw corn stalks
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: palm rapeseed oil
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: cornbioplymers from corn
# Error: starchbioplymers from corn
# Error: animal fatsrenewable diesel from animal fats
# Error: corn stover cobs
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: rice straw corn stalks
# Error: rice straw corn stalks
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: palm rapeseed oil
# Error: corn stover cobs
# Error: corn stover cobs
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: mixed biomass natural gas
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# Error: corn stover cobs
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Put Nodelist and Edgelist to JSON file

# %%
with open('nodesedges.json', 'w') as outfile:
    outfile.write(strjson + stredges)

# %%
We create a function that return the capability matrix of the whole database.

# %%
def get_total_matrix(normalization):
    
    # define queries
    # non intersecting part
    q1 =         """    
                MATCH (a:Asset)-[:CONTAINS]->(fs:Feedstock)
                MATCH (a:Asset)-[:CONTAINS]->(out:Output)
                MATCH (a:Asset)-[:CONTAINS]->(pt:ProcessingTech)
                RETURN fs.term, pt.term, out.term, count(a)
                """
    
    process_variables = ['Feedstock', 'Output', 'ProcessingTech']
    
    # interesecting part
    q2 =        """    
                MATCH (a:Asset)-[:CONTAINS]->(fs:{})
                MATCH (a:Asset)-[:CONTAINS]->(t:{})
                WHERE fs<>t
                RETURN fs.term, t.term, count(a)
                """
    # total assets of year
    q3 =        """
                MATCH (n:Asset)
                RETURN count(n)
                """
    
    # treat incoming data
    total_documents = DataFrame(connection_to_graph.data(q3)).as_matrix()[0][0]
    
    # get data
    data_q1 = DataFrame(connection_to_graph.data(q1)).as_matrix()
    
    # create matrix
    total_matrix = np.zeros([len(nodes), len(nodes)])
    
    # for no intersections data
    for row in data_q1:
        # the last column is the frequency (count)
        frequency = row[0]
        indexes = [nodes.index(element) for element in row[1::]]
        # add frequency value to matrix position not inter
        for pair in itertools.combinations(indexes, 2):
            total_matrix[pair[0], pair[1]] += frequency
            total_matrix[pair[1], pair[0]] += frequency
    
    # for intersecting data
    for category in process_variables:
        process_data = DataFrame(connection_to_graph.data(q2.format(category, category))).as_matrix()
        for row in process_data:
            frequency = row[0]
            indexes = [nodes.index(element) for element in row[1::]]
            # add frequency value to matrix position inter
            for pair in itertools.combinations(indexes, 2):
                total_matrix[pair[0], pair[1]] += frequency / 2 # Divided by two because query not optimized
                total_matrix[pair[1], pair[0]] += frequency / 2 # Divided by two because query not optimized
    
    # normalize
    norm_total_matrix = total_matrix  / total_documents
    
    # dynamic return 
    if normalization == True:
        return norm_total_matrix
    else: 
        return total_matrix

# %% [markdown]
# Let us visualize the normalized and non normalized versions.
#
# We create a function that gives borders to our graphs.

# %%
def borders(width, color, size=get_total_matrix(normalization=False).shape[1]):
    plt.axhline(y=0, color='k',linewidth=width)
    plt.axhline(y=size, color=color,linewidth=width)
    plt.axvline(x=0, color='k',linewidth=width)
    plt.axvline(x=size, color=color,linewidth=width)

# %% [markdown]
# And we plot.

# %%
## call functions
colors = 'binary'

year_in_focus = 2016
# create a subplot
plt.subplots(2,1,figsize=(17,17))

# first heatmap
plt.subplot(121)
vmax = 1000
sns.heatmap(get_total_matrix(normalization=False) , cmap=colors,  cbar=True,cbar_kws={"shrink": .2}, square=True, xticklabels=False, yticklabels=False, vmax=vmax)
borders(1.5, 'k')
plt.title('Capability Matrix Absolute')

# second heatmap
plt.subplot(122)
vmax = 0.1
sns.heatmap(get_total_matrix(normalization=True) , cmap=colors,  cbar=True,cbar_kws={"shrink": .2}, square=True, xticklabels=False, yticklabels=False, vmax=vmax)
borders(1.5, 'k')
plt.title('Capability Matrix Normalized')
plt.show()

# %% [markdown]
# ### Total database matrix: clustered

# %%
whole_database = get_total_matrix(normalization=True)
a = sns.clustermap(whole_database,  figsize=(12, 12), xticklabels = False, yticklabels=False, cmap='binary', square=True)
borders(1.5, 'k')
# plt.show()
a

# %%
cluster_order = []
for i in a.dendrogram_row.reordered_ind:
    cluster_order.append(axis_names[i])

print 'Extract of cluster order:'
cluster_order[50:70]
# Out:
# Extract of cluster order:
# [u'sugarcane bagasse',
#  u'wood chips',
#  u'pine',
#  u'agricultural residues',
#  u'rice straw',
#  u'wheat straw',
#  u'blend',
#  u'succinic acid',
#  u'biobutanol',
#  u'oil extraction',
#  u'microwave',
#  u'natural gas',
#  u'pellets',
#  u'barley',
#  u'poplar',
#  u'sugar beet',
#  u'grains',
#  u'acid hydrolysis',
#  u'consolidated bioprocessing',
#  u'cbp']

# %% [markdown]
# ## 1. Characterisation of Years <a class="anchor" id="one"></a>

# %% [markdown]
# ### 1.1. Years in the database <a class="anchor" id="one-one"></a>

# %% [markdown]
# Not all years in the Neo4j database contain technological assets. For this reason, two lists will be created. A completely chronological one and a database one.

# %%
# query years
years_available_q = """     MATCH (n:Asset)
                            WITH n.year as YEAR
                            RETURN YEAR, count(YEAR)
                            ORDER BY YEAR ASC """

# create a list with the years where records exist
years_available = DataFrame(connection_to_graph.data(years_available_q)).as_matrix()[:, 0][:-1]
years_available = [int(year) for year in years_available]

# create a pure range list
first_year = int(years_available[0])
last_year = int(years_available[-1])
real_years = range(first_year, last_year + 1, 1)

# give information 
print 'The database list starts in {}, ends in {} and contains {} years.'.format(years_available[0], years_available[-1], len(years_available))
print 'The real list starts in {}, ends in {} and contains {} years.'.format(real_years[0], real_years[-1], len(real_years))
# Out:
# The database list starts in 1938, ends in 2019 and contains 38 years.
# The real list starts in 1938, ends in 2019 and contains 82 years.

# %% [markdown]
# Now that we have all of the years available, we can start building the technological capability matrixes.

# %% [markdown]
# ### 1.2. Capability Matrixes of years <a class="anchor" id="one-two"></a>

# %% [markdown]
# #### 1.2.1. Getting the labels <a class="anchor" id="one-two-one"></a>

# %% [markdown]
# The final list of terms has 352 terms.

# %% [markdown]
# #### 1.2.2. Function <a class="anchor" id="one-two-two"></a>

# %% [markdown]
# We start by creating a function that given a certain year, returns the year's capability matrix.

# %%
def get_year_matrix(year, normalization=True):
    
    # define queries
    # non intersecting part
    q1 =         """    
                MATCH (a:Asset)-[:CONTAINS]->(fs:Feedstock)
                MATCH (a:Asset)-[:CONTAINS]->(out:Output)
                MATCH (a:Asset)-[:CONTAINS]->(pt:ProcessingTech)
                WHERE a.year = "{}"
                RETURN fs.term, pt.term, out.term, count(a)
                """.format(year)
    
    process_variables = ['Feedstock', 'Output', 'ProcessingTech']
    
    # interesecting part
    q2 =        """    
                MATCH (a:Asset)-[:CONTAINS]->(fs:{})
                MATCH (a:Asset)-[:CONTAINS]->(t:{})
                WHERE fs<>t AND a.year = "{}"
                RETURN fs.term, t.term, count(a)
                """
    # total assets of year
    q3 =        """
                MATCH (n:Asset)
                WITH n.year as YEAR
                RETURN YEAR, count(YEAR)
                ORDER BY YEAR ASC
                """
    
    # treat incoming data
    raw_data_q3 = DataFrame(connection_to_graph.data(q3)).as_matrix()
    index_of_year = list(raw_data_q3[:, 0]).index('{}'.format(year))
    total_documents = raw_data_q3[index_of_year, 1]

    # get data
    data_q1 = DataFrame(connection_to_graph.data(q1)).as_matrix()
    
    # create matrix
    year_matrix = np.zeros([len(axis_names), len(axis_names)])
    
    # for no intersections data
    for row in data_q1:
        # the last column is the frequency (count)
        frequency = row[0]
        indexes = [axis_names.index(element) for element in row[1::]]
        # add frequency value to matrix position not inter
        for pair in itertools.combinations(indexes, 2):
            year_matrix[pair[0], pair[1]] += frequency
            year_matrix[pair[1], pair[0]] += frequency
    
    # for intersecting data
    for category in process_variables:
        process_data = DataFrame(connection_to_graph.data(q2.format(category, category, year))).as_matrix()
        for row in process_data:
            frequency = row[0]
            indexes = [axis_names.index(element) for element in row[1::]]
            # add frequency value to matrix position inter
            for pair in itertools.combinations(indexes, 2):
                year_matrix[pair[0], pair[1]] += frequency / 2 # Divided by two because query not optimized
                year_matrix[pair[1], pair[0]] += frequency / 2 # Divided by two because query not optimized
    
    # normalize
    norm_year_matrix = year_matrix  / total_documents
    
    # dynamic return 
    if normalization == True:
        return norm_year_matrix
    else: 
        return year_matrix

# %% [markdown]
# We finally test our function with the year 2016.

# %%
year = 2017
print 'The matrix from {} has shape {} a max value of {}, a min value of {} and a mean of {}.'.format(year, get_year_matrix(year).shape, np.amax(get_year_matrix(year)), np.amin(get_year_matrix(year)), np.mean(get_year_matrix(year)))
# Out:
# The matrix from 2017 has shape (352, 352) a max value of 0.229850746269, a min value of 0.0 and a mean of 0.000211213110583.

# %% [markdown]
# Let us print the capability matrices of 2016 normalized and absolute versions.

# %%
## call functions
colors = 'binary'
vmin = 0.0000
vmax = 0.05

year_in_focus = 2016
# create a subplot
plt.subplots(2,1,figsize=(17,17))

# first heatmap
plt.subplot(121)
sns.heatmap(get_year_matrix(year_in_focus, normalization=False) , cmap=colors,  cbar=True,cbar_kws={"shrink": .2}, square=True, xticklabels=False, yticklabels=False)
borders(1.5, 'k')
plt.title('Capability Matrix Absolute: {}'.format(year_in_focus))

# second heatmap
plt.subplot(122)
sns.heatmap(get_year_matrix(year_in_focus, normalization=True) , cmap=colors,  cbar=True,cbar_kws={"shrink": .2}, square=True, xticklabels=False, yticklabels=False, vmin=vmin, vmax=vmax)
borders(1.5, 'k')
plt.title('Capability Matrix Normalized: {}'.format(year_in_focus))
plt.show()

# %%
## call functions
color1 = 'Blues'
color3 = 'Reds'
rwhite = ListedColormap(['white', 'red'])
gwhite = ListedColormap(['white', 'green'])
blwhite = ListedColormap(['white', 'blue'])
bwhite = ListedColormap(['white', 'grey'])
year_in_focus = 2017
graph_holder = 0.001

original = get_year_matrix(year_in_focus, normalization=False)

threshold = len(f_terms)
f_mask = np.ones(original.shape)
f_mask[0:threshold, 0:threshold] = 0

threshold = len(f_terms) + len(pt_terms)
pt_mask = np.ones(original.shape)
pt_mask[len(f_terms):threshold , len(f_terms):threshold] = 0
o_mask = np.ones(original.shape)
o_mask[threshold:: , threshold::] = 0

plt.subplots(1,1,figsize=(9, 9))
plt.subplot(111)
sns.heatmap(original, cmap=bwhite, center=0.001, cbar=None, square=True, xticklabels=False, yticklabels=False)
sns.heatmap(original, mask = f_mask, cmap=rwhite, center=graph_holder, cbar=None, square=True, xticklabels=False, yticklabels=False)
sns.heatmap(original, mask = pt_mask, cmap=gwhite, center=graph_holder, cbar=None, square=True, xticklabels=False, yticklabels=False)
sns.heatmap(original, mask = o_mask, cmap=blwhite, center=graph_holder, cbar=None, square=True, xticklabels=False, yticklabels=False)
borders(1.5, 'k')

plt.title('Capability Matrix Absolute: {}'.format(year_in_focus))
plt.show()

# %%
## call functions
colors = 'binary'
year_in_focus = 2017
# create a subplot

plt.subplots(1,1,figsize=(9, 9))
plt.subplot(111)
sns.heatmap(get_year_matrix(year_in_focus, normalization=True) , cmap=colors,  cbar=True,cbar_kws={"shrink": .2}, square=True, xticklabels=False, yticklabels=False, vmin=0.00, vmax=0.05)
borders(1.5, 'k')

plt.title('Capability Matrix Normalized: {}'.format(year_in_focus))
plt.show()

# %% [markdown]
# ### 1.3. Year profiles <a class="anchor" id="one-three"></a>

# %% [markdown]
# In order to analyse the correlation of the years between themselves, we will need to transform each year matrix into a list. Since the matrix is symmetrical, we will only need the upper triangle. For control purposes, we have designed our own upper triangulization matrix.

# %%
def get_list_from(matrix):
    only_valuable = []
    extension = 1
    for row_number in range(matrix.shape[0]):
        only_valuable.append(matrix[row_number, extension:matrix.shape[0]].tolist()) # numpy functions keep 0s so I hard coded it. 
        extension += 1 
    return [element for column in only_valuable for element in column ]

# %% [markdown]
# Let us print the capability lists of two example years.

# %%
# apply functions to both countries
a_list = get_list_from(get_year_matrix(2012, normalization=True))
b_list = get_list_from(get_year_matrix(2013, normalization=True))

# create a matrix where each row is a list of a country
corelation = np.vstack((a_list, b_list))
print corelation.shape
good_cols = [i for i in range(corelation.shape[1]) if np.sum(corelation[:, i]) != 0]
        
good_corelation = corelation[:, good_cols]
print good_corelation.shape

# plot the matrix 
plt.subplots(1,1,figsize=(20, 5))
plt.subplot(111)
sns.heatmap(good_corelation,cmap=ListedColormap(['white', 'black']), center=0.00000001, cbar=None, square=False, yticklabels=['2012', '2013'], xticklabels=False)
plt.yticks(rotation=0)
plt.title('Year Capability List Visualization', size=15)
plt.show()
# Out:
# (2, 61776)
# (2, 3700)

# %% [markdown]
# It is already apparent that these two consecutive years are highly correlated.

# %% [markdown]
# ## 2. Year Correlation Matrix <a class="anchor" id="two"></a>

# %% [markdown]
# ### 2.1. Considerations <a class="anchor" id="two-one"></a>

# %% [markdown]
# As previously done with countries, a year correlation matrix will be built.
#
# We first define the scope of the matrix, by defining which years will be analyzed.

# %%
number_of_years = len(years_available)
years_in_matrix = years_available
years_correlation = np.zeros([number_of_years, number_of_years])
print years_in_matrix
# Out:
# [1938, 1975, 1980, 1981, 1983, 1985, 1986, 1988, 1989, 1990, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %% [markdown]
# By looping over each year and calculating its capability list, we create a correlation matrix.

# %%
data = np.load('Data/year_capability_dict.npy').item()
# for every year A
for row in range(number_of_years):
    year_1_list = data[years_in_matrix[row]] # get its capability list
    
    # for every year B
    for column in range(number_of_years):
        year_2_list = data[years_in_matrix[column]] # get its capability list
        years_correlation[row, column] = stats.pearsonr(year_1_list, year_2_list)[0] # calculate the correlation between the two and place it in the matrix

# %% [markdown]
# We now print the correlation matrix.

# %%
plt.subplots(1,1,figsize=(9, 9))
plt.subplot(111)
sns.heatmap(years_correlation,square=True, cbar=True,cbar_kws={"shrink": .2}, yticklabels=years_in_matrix, xticklabels=years_in_matrix)
plt.title('Years Correlation Matrix: Unordered', size=13)
plt.show()

# %% [markdown]
# There seems to be a lot of data missing.
#
# Let's plot the amount of records in our databse over time to get a better sense on how to approach the problem.

# %%
# get all of the data
data = DataFrame(connection_to_graph.data(years_available_q)).as_matrix()
raw = [int(a) for a in data[:-1, 0]]
timeline = range(min(raw), max(raw))
qtties = []

# build a timeline and number of records. 
for year in timeline:
    if year not in raw:
        qtties.append(0)
    else: 
        idx = list(data[:, 0]).index(str(year))
        qtties.append(data[idx, 1])

# re arrange it
amountOfRecords = np.column_stack((timeline, qtties))

# plot the graph
plt.style.use('seaborn-darkgrid')
plt.subplots(1,1,figsize=(16, 5))
plt.subplot(111)
plt.title("Number of assets over time")
plt.xlabel("Year")
plt.ylabel("Number of Available assets")
plt.plot(timeline, qtties)
plt.show()

# %% [markdown]
# ### 2.2. Final Year Correlation Matrix <a class="anchor" id="two-two"></a>

# %% [markdown]
# To counteract the fact that our dataset is not uniformily distributed across the years, we will only consider the last 15 years. [2004-2018]

# %%
number_of_years = 22
years_in_matrix = years_available[:-1][-number_of_years:]
years_correlation = np.zeros([number_of_years, number_of_years])

# %% [markdown]
# We now rebuild and plot the heatmap of correlations.

# %%
data = np.load('Data/year_capability_dict.npy').item() # for efficiency

# create the matrix again. 
for row in range(number_of_years):
    year_1_list = data[years_in_matrix[row]]
    for column in range(number_of_years):        
        year_2_list = data[years_in_matrix[column]]
        years_correlation[row, column] = stats.pearsonr(year_1_list, year_2_list)[0]

# print it
plt.subplots(1,1,figsize=(8, 8))
plt.subplot(111)
sns.heatmap(years_correlation, cbar=True, cbar_kws={"shrink": .5},square=True, yticklabels=years_in_matrix, xticklabels=years_in_matrix)
plt.title('Years Correlation Matrix: Chronologically Ordered, last 15 years', size=13)
plt.show()

# %% [markdown]
# ### 2.3. Year correlation matrix clustering <a class="anchor" id="two-three"></a>

# %% [markdown]
# Let us reorder the heatmap according to hierarchical clustering.

# %%
# plot the clustermap
a = sns.clustermap(years_correlation,  figsize=(8, 8), xticklabels = years_in_matrix, yticklabels=years_in_matrix)
plt.show()

# %% [markdown]
# ## 3. Correlation of years over time <a class="anchor" id="three"></a>

# %% [markdown]
# Let us see how related is each year in our matrix with the one before it. In this way we might more easily detect discripancies.

# %%
# remove first year
advanced_timeline = years_in_matrix[1::]
corr_with_pre = []

# iterate years and see their correlation 
row = 1
col = 0
for year in advanced_timeline:
    corr_with_pre.append(years_correlation[row, col])
    row = row + 1
    col = col + 1

# plot
plt.subplots(1,1,figsize=(15,7))
pal = sns.color_palette("Reds", len(data))
sns.barplot(np.arange(len(corr_with_pre)), corr_with_pre, palette=np.array(pal[::-1])[np.asarray(corr_with_pre).argsort().argsort()] )
plt.xticks(np.arange(len(corr_with_pre)), advanced_timeline, rotation=90, fontsize=11)
plt.title('Correlation of year with previous year')
plt.ylabel('Pearson Correlation Index')
plt.show()

# %% [markdown]
# Some years, such as 2006 or 2007 appear to have very low correlations with the years after. There seems to be an overall tendency of augmenting correlation with the years.

# %% [markdown]
# ## 4. Research terms over time <a class="anchor" id="four"></a>

# %% [markdown]
# The following part of the analysis wil focus on how certain process variables (Feedstocks, Processing Technologies and Outputs) evolve over time.
#
# This can help in answering questions such as for example:
#
# - Is the focus on a certain processing technology constant over time?
# - Is this evolution correlated with other external factors?

# %% [markdown]
# Let's start by creating a function such as:
#
# f(term, type of process variable) = [array with the number of records containing the term in each year]

# %%
from __future__ import division
def get_records_of(startYear, endYear, term, process_type):
    
    # make query    
    yearRangeQuery = """ MATCH (a:Asset)-[:CONTAINS]->(fs:{})
                WHERE fs.term = "{}"
                AND (toInteger(a.year)>={} AND toInteger(a.year)<={}) 
                AND NOT a.year = "Null"
                RETURN  a.year, count(a)
                ORDER BY a.year   """.format(process_type, term, startYear, endYear)
    
    # extract matrix
    rawQuery = DataFrame(connection_to_graph.data(yearRangeQuery)).as_matrix()
    
    # create matrix to store years, docs and total docs
    normalTimeline = np.arange(startYear, endYear + 1)
    completeMatrix = np.transpose(np.vstack((normalTimeline, normalTimeline, normalTimeline, normalTimeline)))    
    completeMatrix[:, 1::] = 0 

    # add number of docs found by query to matrix
    for i in range(len(rawQuery[:, 0])):
        for j in range(len(completeMatrix[:, 0])):
            if int(rawQuery[i, 0]) == completeMatrix[j, 0]:
                completeMatrix[j, 1] = rawQuery[i, 1] 
    
    # add total number of docs in that year to matrix
    for i in range(len(completeMatrix[:, 0])):
        for j in range(len(amountOfRecords[:, 0])):
            if completeMatrix[i, 0] == amountOfRecords[j, 0]:
                completeMatrix[i, 2] = amountOfRecords[j, 1]

    # create a list of the normalized results 
    normalizedRecords = []
    for i in range(len(completeMatrix[:, 0])):
        if completeMatrix[i, 2] != 0:
            normalizedRecords.append(float(completeMatrix[i, 1])/float(completeMatrix[i, 2]))
        else:
            normalizedRecords.append(0)
         
    # return a dictionnary for easy access to all variables
    result = {}
    result['range']  = completeMatrix[:, 0].tolist()
    result['nominal'] = completeMatrix[:, 1].tolist()
    result['total'] = completeMatrix[:, 2].tolist()        
    result['normalized'] = normalizedRecords
    
    return result

# %% [markdown]
# Now that the function is built, we can plot virtually any evolution.

# %% [markdown]
# ### 4.1. Evolution of output terms <a class="anchor" id="four-one"></a>
#
# Let us see the evolution of records of biogas Vs. ethanol as an example.

# %%
listOfOutputs = ['biogas', 'ethanol', 'biodiesel']
start_year = 1990
end_year = 2017

# plot the graph
plt.style.use('seaborn-darkgrid')
plt.subplots(1,1,figsize=(16, 5))
plt.subplot(111)
plt.title("Evolution of Records with focus on Output")
plt.xlabel("Year")
plt.ylabel("Normalized Quantity")

for name in listOfOutputs:
    nameData = get_records_of(start_year,end_year,name, 'Output')
    plt.plot(nameData['range'], nameData['normalized'], label=name)

plt.legend()
plt.show()

# %% [markdown]
# ### 4.2. Evolution of processing technology terms <a class="anchor" id="four-two"></a>
#
# Let us develop the same procedure for some processing technologies.

# %%
listOfProcTech = ['fermentation','enzymatic hydrolysis','hydrolysis' ]
start_year = 1990
end_year = 2017

# plot the graph
plt.style.use('seaborn-darkgrid')
plt.subplots(1,1,figsize=(16, 5))
plt.subplot(111)
plt.title("Evolution of Records with focus on Processing Technologies")
plt.xlabel("Year")
plt.ylabel("Normalized Quantity")

for name in listOfProcTech:
    nameData = get_records_of(start_year,end_year,name, 'ProcessingTech')
    plt.plot(nameData['range'], nameData['normalized'], label=name)

plt.legend()
plt.show()

# %% [markdown]
# ### 4.3. Evolution of feedstock terms <a class="anchor" id="four-three"></a>
#
# Let us develop the same procedure for feedstock.

# %%
listOfFeed = ['sugar','wood','paper', 'algae', 'waste']
start_year = 1990
end_year = 2017

# plot the graph
plt.style.use('seaborn-darkgrid')
plt.subplots(1,1,figsize=(16, 5))
plt.subplot(111)
plt.title("Evolution of Records with focus on Feedstocks")
plt.xlabel("Year")
plt.ylabel("Normalized Quantity")

for name in listOfFeed:
    nameData = get_records_of(start_year,end_year,name, 'Feedstock')
    plt.plot(nameData['range'], nameData['normalized'], label=name)

plt.legend()
plt.show()

# %% [markdown]
# ## 5. Contextual relationships <a class="anchor" id="five"></a>
#
# ### 5.1. Oil <a class="anchor" id="five-one"></a>

# %% [markdown]
# We start by comparing the evolution of the outputs above studied with the average oil price per gallon found in the [following](https://fred.stlouisfed.org/series/GASREGCOVM#0) website.
#
# We import the data, and convert monthly prices to yearly averages with the bellow code.
#
# - [Price per gallon in US dollars](https://fred.stlouisfed.org/series/GASREGCOVM#0)
# - [Price per barrel inflation adjusted in US dollars](https://inflationdata.com/Inflation/Inflation_Rate/Historical_Oil_Prices_Table.asp)

# %%
# get price per gallon in US dollars
oil_data = pd.read_csv('Data/GasData.csv', delimiter=',', header=None).as_matrix()[1::, :]
gallon = []
oil_years = list(set([int(e[0:4]) for e in oil_data[:, 0]]))[:-1]
for year in oil_years:
    addition = 0
    months = 0
    for row in oil_data:
        if str(year) in row[0]:
            addition += float(row[1])
            months += 1
    average = addition / months
    gallon.append(average)

# get price per barrel data 
barrel = pd.read_csv('Data/GasDataNormalized.csv', delimiter=';', header=None).as_matrix()[:, 1].tolist()

oil_index = {'gallon':gallon, 'barrel':barrel}

# %% [markdown]
# **Relationship Over Time**

# %% [markdown]
# Let us visualize how the evolution of the price of gas relates to the normalized quantity of assets over time, in a chronological graph.

# %%
# define subplots
fig, ax1 = plt.subplots(figsize=(15,7))
listOfOutputs = ['biogas', 'bioplastic', 'butanol']
colors = ['b', 'y', 'g']
start_year = 1990
end_year = 2017
price_type = 'barrel'

# first axis

for position, outputName in enumerate(listOfOutputs):
    nameData = get_records_of(start_year, end_year, outputName, 'Output')
    ax1.plot(nameData['range'], nameData['normalized'], label=outputName, color=colors[position], ls='--', alpha=0.5) 
    

ax1.set_xlabel('Years')
ax1.set_ylabel('Number of relative records')
ax1.tick_params('y')
ax1.set_title('Oil Price Vs. Asset Quantity')
ax1.legend(loc=2, frameon=True)
ax1.grid(False)

# second axis
ax2 = ax1.twinx()
ax2.plot(oil_years,oil_index[price_type], color='r', label='Oil Price')
ax2.set_ylabel('Price of {} of oil $US'.format(price_type), color='r')
ax2.tick_params('y', colors='r')
ax2.legend(loc=1, frameon=True)

# expose
plt.show()

# %% [markdown]
# **Scatter Visualization**
#
# To study this relationship in a more in depth fashion we create a process that given a certain term gives us the relationship with the price of gas.

# %%
# define terms
outPutToCompare = 'butanol'
typeOfProcessVariable = 'Output'
price_type = 'gallon'

# get data
data = get_records_of(1990, 2017, outPutToCompare, typeOfProcessVariable)['normalized']

# plot the figure
fig, ax1 = plt.subplots(figsize=(15,7))
sns.regplot(np.asarray(oil_index[price_type]), np.asarray(data) ,fit_reg=True, marker="+", color = 'g')
plt.title('Gas price relation with quantity of Assets: {}'.format(outPutToCompare))
plt.xlabel('Price of {} of oil in US$ in Year'.format(price_type))
plt.ylabel('Quantity of Asset {} in Year'.format(outPutToCompare))
plt.show()

# get correlation indexes
correlationIndexes =  stats.pearsonr(np.asarray(oil_index[price_type]), np.asarray(get_records_of(1990, 2017, outPutToCompare, 'Output')['normalized']))
print 'Pearson Correlation Index: ', correlationIndexes[0]
print 'P-value: ', correlationIndexes[1]
# Out:
# Pearson Correlation Index:  0.8445465111603638
# P-value:  1.6031894575347735e-08

# %% [markdown]
# In the above graph each datapoint corresponds to a year.

# %% [markdown]
# **Biggest Positive Correlations**

# %%
# query for data
term_names_query = """  MATCH (a:Asset)-[:CONTAINS]->(fs:Output)
                        WHERE (toInteger(a.year)>=1990 AND toInteger(a.year)<=2017) 
                        AND NOT a.year = "Null"
                        RETURN  fs.term, count(a)
                        ORDER BY count(a) DESC"""

# get data from past scripts
oil_type = 'gallon'
term_names = list(DataFrame(connection_to_graph.data(term_names_query)).as_matrix()[:, 1].tolist())
correlations = []
p_values = []

# for every term, get its correlation with the price of oil
for term in term_names:
    data = get_records_of(1990, 2017, term, 'Output')['normalized']
    correlations.append(stats.pearsonr(data, oil_index[oil_type])[0])
    p_values.append(stats.pearsonr(data, oil_index[oil_type])[1])


# create a pandas dataframe for pretty printing. 
oilDataFrame = pd.DataFrame(
    {'Output Name': term_names,
     'Pearson Correlation Index': correlations,
     'P-value': p_values
    })
oilDataFrame = oilDataFrame.sort_values('Pearson Correlation Index', ascending=False)

# print context
print 'The relationship between relative number of documents and price of oil over time:'
top = 10

# print data
print 'TOP {}:'.format(top)
display(oilDataFrame[:top])
# Out:
# The relationship between relative number of documents and price of oil over time:
# TOP 10:
#                Output Name       P-value  Pearson Correlation Index
# 7                  butanol  1.603189e-08                   0.844547
# 19              bioplastic  2.463734e-07                   0.804599
# 1                biodiesel  7.978637e-07                   0.784034
# 21  fatty acid ethyl ester  1.427601e-06                   0.772960
# 30             adipic acid  1.048009e-05                   0.729790
# 3               bioethanol  2.862862e-05                   0.704439
# 9                     syng  3.649295e-05                   0.697899
# 15              biobutanol  5.140385e-05                   0.688369
# 8       cellulosic ethanol  1.301892e-04                   0.660616
# 14             biopolymers  3.263515e-04                   0.630094

# %% [markdown]
# **Biggest Negative Correlations**

# %%
# same approach but value negative correlations
term_names_query = """  MATCH (a:Asset)-[:CONTAINS]->(fs:Output)
                        WHERE (toInteger(a.year)>=1990 AND toInteger(a.year)<=2017) 
                        AND NOT a.year = "Null"
                        RETURN  fs.term, count(a)
                        ORDER BY count(a) DESC"""
oil_type = 'gallon'
term_names = list(DataFrame(connection_to_graph.data(term_names_query)).as_matrix()[:, 1].tolist())
correlations = []
p_values = []
for term in term_names:
    data = get_records_of(1990, 2017, term, 'Output')['normalized']
    correlations.append(stats.pearsonr(data, oil_index[oil_type])[0])
    p_values.append(stats.pearsonr(data, oil_index[oil_type])[1])

oilDataFrame = pd.DataFrame(
    {'Output Name': term_names,
     'Pearson Correlation Index': correlations,
     'P-value': p_values
    })
oilDataFrame = oilDataFrame.sort_values('Pearson Correlation Index', ascending=False)



print 'The relationship between relative number of documents and price of oil over time:'
bottom = -10

print 'BOTTOM {}:'.format(bottom)
display(oilDataFrame[bottom:])
# Out:
# The relationship between relative number of documents and price of oil over time:
# BOTTOM -10:
#                  Output Name   P-value  Pearson Correlation Index
# 16                   naphtha  0.677733                   0.082145
# 44        biodiesel blending  0.683315                   0.080645
# 45          ethanol blending  0.683315                   0.080645
# 18          renewable diesel  0.716673                   0.071767
# 11            renewable fuel  0.944557                   0.013770
# 17             succinic acid  0.956893                   0.010703
# 40                      rdif  0.629618                  -0.095276
# 34  electricity from biomass  0.456174                  -0.146748
# 5                   gasoline  0.371514                  -0.175570
# 10                   pellets  0.268436                  -0.216520

# %% [markdown]
# ### 5.2. Sugar <a class="anchor" id="five-two"></a>

# %% [markdown]
# In this part we will make the same analysis but taking an example of a feedstock: sugar.
#
# Data was obtained [here.](http://databank.worldbank.org/data/reports.aspx?source=global-economic-monitor-commodities#)
#
# We start by importing the data.

# %%
sugar_data = pd.read_csv('Data/Sugar_Price.csv', delimiter=';', header=None).as_matrix()
sugar = {}
sugar['years'] = [int(e) for e in sugar_data[:, 0]]
sugar['nominal'] = [e for e in sugar_data[:, 1]]
sugar['real'] =  [e for e in sugar_data[:, 2]]

# %% [markdown]
# **Relationship Over Time**
#
# Let us see the evolution of Sugar prices side by side with the evolution of certain feedstocks in our database.

# %%
# define subplots
fig, ax1 = plt.subplots(figsize=(15,7))
feedstock_list = ['sugar', 'wood', 'sugarcane', 'sugar beet', 'cellulosic sugars']
colors = ['gold', 'mediumblue', 'm', 'green', 'k']

start_year = 1990
end_year = 2017
sugar_price_type = 'real'

# first axis
for position,feedstock in enumerate(feedstock_list):
    data = get_records_of(start_year, end_year, feedstock, 'Feedstock')
    ax1.plot(data['range'], data['normalized'], label=feedstock, ls='--', color=colors[position])
    
ax1.set_xlabel('Years')
ax1.set_ylabel('Relative number of records')
ax1.tick_params('y')
ax1.set_title('Sugar Prices Vs. Asset Quantity')
ax1.legend(loc=3, frameon=True)
ax1.grid(False)

# second axis
ax2 = ax1.twinx()
ax2.plot(sugar['years'], sugar[sugar_price_type], color='r', label='Sugar Price', ls='-')
ax2.set_ylabel('Price per kilo of sugar in $US (inflation adjusted)', color='r')
ax2.tick_params('y', colors='r')
ax2.legend(loc=1, frameon=True)

# expose
plt.show()

# %% [markdown]
# **Scatter Example**
#
# Let us see a scatter plot where each point is a year and the x and y axis correpond to the price of sugar and quantity of assets respectively.

# %%
outPutToCompare = 'sugarcane'
typeOfProcessVariable = 'Feedstock'
price_type = 'real'


data = get_records_of(1990, 2017, outPutToCompare, typeOfProcessVariable)['normalized']

fig, ax1 = plt.subplots(figsize=(15,7))
sns.regplot(np.asarray(sugar[price_type]), np.asarray(data) ,fit_reg=True, marker="+", color = 'b')
plt.title('Sugar price relation with quantity of Assets: {}'.format(outPutToCompare))
plt.xlabel('Price of sugar US$ per kilo in Year ({})'.format(price_type))
plt.ylabel('Quantity of Asset {} in Year'.format(outPutToCompare))

plt.show()

# %% [markdown]
# **Biggest Positive Correlations**
#
# Which are the feedstocks who are more related to the price of sugar per kilo in what regards the number of records?

# %%
term_names_query = """  MATCH (a:Asset)-[:CONTAINS]->(fs:Feedstock)
                        WHERE (toInteger(a.year)>=1990 AND toInteger(a.year)<=2017) 
                        AND NOT a.year = "Null"
                        RETURN  fs.term, count(a)
                        ORDER BY count(a) DESC"""
price_type = 'nominal'
term_names = list(DataFrame(connection_to_graph.data(term_names_query)).as_matrix()[:, 1].tolist())
correlations = []
p_values = []
for term in term_names:
    data = get_records_of(1990, 2017, term, 'Feedstock')['normalized']
    correlations.append(stats.pearsonr(data, sugar[price_type])[0])
    p_values.append(stats.pearsonr(data, sugar[price_type])[1])

sugarDataframe = pd.DataFrame(
    {'Feedstock Name': term_names,
     'Pearson Correlation Index': correlations,
     'P-value': p_values
    })
sugarDataframe = sugarDataframe.sort_values('Pearson Correlation Index', ascending=False)



print 'The relationship between relative number of documents and price per kilo of sugar:'
top = 10

print 'TOP {}:'.format(top)
display(sugarDataframe[:top])
# Out:
# The relationship between relative number of documents and price per kilo of sugar:
# TOP 10:
#              Feedstock Name       P-value  Pearson Correlation Index
# 26                sugarcane  6.074365e-07                   0.789014
# 107       cellulosic sugars  1.263220e-06                   0.775341
# 43                 jatropha  1.521222e-06                   0.771713
# 34                  sorghum  3.083429e-06                   0.757299
# 64              dry biomass  3.454736e-06                   0.754884
# 75                    beets  4.105286e-06                   0.751165
# 99   dedicated energy crops  6.915371e-06                   0.739525
# 1                     algae  1.103076e-05                   0.728562
# 100           hybrid poplar  1.490683e-05                   0.721206
# 25                      soy  2.631077e-05                   0.706675

# %% [markdown]
# **Biggest Negative Correlations**

# %%
term_names_query = """  MATCH (a:Asset)-[:CONTAINS]->(fs:Feedstock)
                        WHERE (toInteger(a.year)>=1990 AND toInteger(a.year)<=2017) 
                        AND NOT a.year = "Null"
                        RETURN  fs.term, count(a)
                        ORDER BY count(a) DESC"""
price_type = 'nominal'
term_names = list(DataFrame(connection_to_graph.data(term_names_query)).as_matrix()[:, 1].tolist())
correlations = []
p_values = []
for term in term_names:
    data = get_records_of(1990, 2017, term, 'Feedstock')['normalized']
    correlations.append(stats.pearsonr(data, sugar[price_type])[0])
    p_values.append(stats.pearsonr(data, sugar[price_type])[1])

sugarDataframe = pd.DataFrame(
    {'Feedstock Name': term_names,
     'Pearson Correlation Index': correlations,
     'P-value': p_values
    })
sugarDataframe = sugarDataframe.sort_values('Pearson Correlation Index', ascending=False)



print 'The relationship between relative number of documents and price per kilo of sugar:'
bottom = -10

print 'Bottom {}:'.format(bottom * -1)
display(sugarDataframe[bottom:])
# Out:
# The relationship between relative number of documents and price per kilo of sugar:
# Bottom 10:
#       Feedstock Name   P-value  Pearson Correlation Index
# 93         wood fuel  0.336664                  -0.188530
# 72         waste oil  0.329527                  -0.191282
# 136   particle board  0.289545                  -0.207425
# 156            durum  0.279399                  -0.211741
# 178  citrus residues  0.260452                  -0.220080
# 123      beef tallow  0.240798                  -0.229158
# 53           sawdust  0.223542                  -0.237542
# 138      trap grease  0.212719                  -0.243025
# 79        wood waste  0.210637                  -0.244102
# 5               wood  0.137684                  -0.287685

# %% [markdown]
# **NON SERIES TIME ANALYSIS IS A LIMITATION.**

# %% [markdown]
# ## 6. Comparing Years <a class="anchor" id="six"></a>
#
# In this part of the analysis the goal is two understand what exact capabilities differ from year to year. More exactly, how does one particular capability evolve over the course of two or more years.
#
# For example, if in year X1, Y1% of the assets related to sugar, what is the percentage Y2% in year X2?
#
# ### 6.1. Visualizing the differences  <a class="anchor" id="six-one"></a>

# %% [markdown]
# Let us visualize two different years side by side.

# %%
## call functions
first_year = 2010
second_year = 2017
colors='binary'

graph_holder = 0.005

fst_year_matrix = get_year_matrix(first_year, normalization=False)
scnd_year_matrix = get_year_matrix(second_year, normalization=False)

# create a subplot
plt.subplots(2,1,figsize=(17,17))

# first heatmap
plt.subplot(121)
sns.heatmap(fst_year_matrix , cmap=colors,  cbar=True,cbar_kws={"shrink": .2}, square=True, xticklabels=False, yticklabels=False, vmax=graph_holder)
borders(1.5, 'k')
plt.title('Capability Matrix: {}'.format(first_year))

# second heatmap
plt.subplot(122)
sns.heatmap(scnd_year_matrix , cmap=colors,  cbar=True,cbar_kws={"shrink": .2}, square=True, xticklabels=False, yticklabels=False, vmax=graph_holder)
borders(1.5, 'k')
plt.title('Capability Matrix: {}'.format(second_year))
plt.show()

# %% [markdown]
# Due to the very high number of rows, visualization is rather hard.

# %% [markdown]
# The next step is to create a matrix of absolute diferences between the two examples, for this, we start by subtracting them:

# %%
cap_diff = np.absolute(fst_year_matrix - scnd_year_matrix)

# %% [markdown]
# And we plot these differences.

# %%
plt.subplots(1,1,figsize=(13, 13))
plt.subplot(111)
sns.heatmap(cap_diff, cmap=colors,cbar_kws={"shrink": .2}, square=True, yticklabels=False, xticklabels=False)
borders(1.5, 'k')
plt.title('Differences between {} and {}: Normalized Differences'.format(first_year, second_year), size=13)
plt.show()

# %% [markdown]
# There seem to be some areas where differences clearly exist. Let us investigate these areas in a more in depth fashion.

# %% [markdown]
# ### 6.2. Understanding the differences  <a class="anchor" id="six-two|"></a>

# %% [markdown]
# Let's understand what exact capability pairs are the most 'popular' in each year.
#
# We start by creating a function that returns given a year X, the most popular capability pairs of that year as absolute numbers and percentage of total documents.

# %%
def get_top_hits(yearMatrix, year):
    """
    The function prints the top occurences if fed a matrix of occurences, it also prints other types of valuable info.
    WARNING: Percentages are shown as 0 to 1. 
    """
        
    # list where all the values and indexes of matrix are stored
    top = 10
    values = []
    indexes = []
    no_duplicates = np.triu(yearMatrix, 1)
    total_documents_q = """ MATCH (n:Asset)
                            WHERE n.year="{}"
                            RETURN count(n)
    """.format(year)
    
    total_documents = DataFrame(connection_to_graph.data(total_documents_q)).as_matrix()[0][0]
    matrix_axis_names = axis_names
    
    
    # loop through the matrix
    for row_n in range(yearMatrix.shape[0]):
        for col_n in range(yearMatrix.shape[1]):
            values.append(no_duplicates[row_n, col_n])
            indexes.append((row_n, col_n))
    
    
    # order the indexes and get the top
    Z = [indexes for _,indexes in sorted(zip(values,indexes))]
    extremes = Z[-top :]
    
    
    # create dataframe
    term_Dataframe = pd.DataFrame(
        {'First Term': [matrix_axis_names[e[0]] for e in extremes],
         'Second Term': [matrix_axis_names[e[1]] for e in extremes],
         'Number of Documents': [int(no_duplicates[e[0], e[1]]) for e in extremes], 
         'Percentage' : [no_duplicates[e[0], e[1]] / float(total_documents) for e in extremes], 
        })
    
    # prepare dataframe
    term_Dataframe = term_Dataframe[['First Term', 'Second Term','Number of Documents', 'Percentage']]
    term_Dataframe = term_Dataframe.sort_values('Number of Documents', ascending=False)
    
    
    # print everything
    print 'The top hits for the {} matrix: '.format(year)
    display(HTML(term_Dataframe.to_html(index=False)))
    
    
    print 'The total number of documents is {}.'.format(int(total_documents))
    print 'Note: Percentages are as 0-1 in this table. '

# %% [markdown]
# Let us use this function to try to understand each year.

# %% [markdown]
# Let us get the top term pairs for the year of 2017.

# %%
get_top_hits(fst_year_matrix, first_year)
# Out:
# The top hits for the 2010 matrix:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>First Term</th>
#       <th>Second Term</th>
#       <th>Number of Documents</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fermentation</td>
#       <td>ethanol</td>
#       <td>319</td>
#       <td>0.350935</td>
#     </tr>
#     <tr>
#       <td>hydrolysis</td>
#       <td>ethanol</td>
#       <td>225</td>
#       <td>0.247525</td>
#     </tr>
#     <tr>
#       <td>transesterification</td>
#       <td>biodiesel</td>
#       <td>168</td>
#       <td>0.184818</td>
#     </tr>
#     <tr>
#       <td>anaerobic digestion</td>
#       <td>biogas</td>
#       <td>152</td>
#       <td>0.167217</td>
#     </tr>
#     <tr>
#       <td>catalysis</td>
#       <td>biodiesel</td>
#       <td>131</td>
#       <td>0.144114</td>
#     </tr>
#     <tr>
#       <td>fermentation</td>
#       <td>bioethanol</td>
#       <td>120</td>
#       <td>0.132013</td>
#     </tr>
#     <tr>
#       <td>sugar</td>
#       <td>ethanol</td>
#       <td>106</td>
#       <td>0.116612</td>
#     </tr>
#     <tr>
#       <td>sugar</td>
#       <td>fermentation</td>
#       <td>102</td>
#       <td>0.112211</td>
#     </tr>
#     <tr>
#       <td>hydrolysis</td>
#       <td>bioethanol</td>
#       <td>95</td>
#       <td>0.104510</td>
#     </tr>
#     <tr>
#       <td>enzymatic hydrolysis</td>
#       <td>ethanol</td>
#       <td>85</td>
#       <td>0.093509</td>
#     </tr>
#   </tbody>
# </table>
# The total number of documents is 909.
# Note: Percentages are as 0-1 in this table.

# %% [markdown]
# Let us get the top term pairs for the year of 2010.

# %%
get_top_hits(scnd_year_matrix, second_year)
# Out:
# The top hits for the 2017 matrix:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>First Term</th>
#       <th>Second Term</th>
#       <th>Number of Documents</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fermentation</td>
#       <td>ethanol</td>
#       <td>154</td>
#       <td>0.229851</td>
#     </tr>
#     <tr>
#       <td>anaerobic digestion</td>
#       <td>biogas</td>
#       <td>137</td>
#       <td>0.204478</td>
#     </tr>
#     <tr>
#       <td>pyrolysis</td>
#       <td>bio-oil</td>
#       <td>101</td>
#       <td>0.150746</td>
#     </tr>
#     <tr>
#       <td>hydrolysis</td>
#       <td>ethanol</td>
#       <td>76</td>
#       <td>0.113433</td>
#     </tr>
#     <tr>
#       <td>fermentation</td>
#       <td>bioethanol</td>
#       <td>76</td>
#       <td>0.113433</td>
#     </tr>
#     <tr>
#       <td>sugar</td>
#       <td>ethanol</td>
#       <td>60</td>
#       <td>0.089552</td>
#     </tr>
#     <tr>
#       <td>waste</td>
#       <td>ethanol</td>
#       <td>58</td>
#       <td>0.086567</td>
#     </tr>
#     <tr>
#       <td>sugar</td>
#       <td>fermentation</td>
#       <td>57</td>
#       <td>0.085075</td>
#     </tr>
#     <tr>
#       <td>waste</td>
#       <td>biogas</td>
#       <td>53</td>
#       <td>0.079104</td>
#     </tr>
#     <tr>
#       <td>fermentation</td>
#       <td>biogas</td>
#       <td>53</td>
#       <td>0.079104</td>
#     </tr>
#   </tbody>
# </table>
# The total number of documents is 670.
# Note: Percentages are as 0-1 in this table.

# %% [markdown]
# We can make two observations:
# - These two particular years have generally the same term pairs in their top table.
# - However, the percentages can differ greatly.
#
# *Note: There is a high difference in number of documents. *

# %% [markdown]
# Let us now finally create a side by side comparison.

# %%
# list where all the values and indexes of matrix are stored
frst_perc = get_year_matrix(first_year, normalization=True)
scnd_perc = get_year_matrix(second_year, normalization=True)
differences = frst_perc - scnd_perc
differences = np.absolute(differences)
values = []
indexes = []
no_duplicates = np.triu(differences, 1)
matrix_axis_names = axis_names


top = 20

# loop through the matrix
for row_n in range(differences.shape[0]):
    for col_n in range(differences.shape[1]):
        values.append(no_duplicates[row_n, col_n])
        indexes.append((row_n, col_n))

# print the table 
Z = [indexes for _,indexes in sorted(zip(values,indexes))]
extremes = list(reversed(Z[-top:]))


term_Dataframe = pd.DataFrame(
    {'First Term': [matrix_axis_names[e[0]] for e in extremes],
     'Second Term': [matrix_axis_names[e[1]] for e in extremes],
     '{} Percentage'.format(first_year): [frst_perc[e[0], e[1]] for e in extremes], 
     '{} Percentage'.format(second_year): [scnd_perc[e[0], e[1]] for e in extremes], 
     'Difference in %': [no_duplicates[e[0], e[1]] for e in extremes]
    })

term_Dataframe = term_Dataframe[['First Term', 'Second Term', '{} Percentage'.format(first_year), '{} Percentage'.format(second_year), 'Difference in %']]


display(HTML(term_Dataframe.to_html(index=False)))
print 'Percentages are as 0-1 in this table for easy viz.'
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>First Term</th>
#       <th>Second Term</th>
#       <th>2010 Percentage</th>
#       <th>2017 Percentage</th>
#       <th>Difference in %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>hydrolysis</td>
#       <td>ethanol</td>
#       <td>0.247525</td>
#       <td>0.113433</td>
#       <td>0.134092</td>
#     </tr>
#     <tr>
#       <td>transesterification</td>
#       <td>biodiesel</td>
#       <td>0.184818</td>
#       <td>0.050746</td>
#       <td>0.134072</td>
#     </tr>
#     <tr>
#       <td>fermentation</td>
#       <td>ethanol</td>
#       <td>0.350935</td>
#       <td>0.229851</td>
#       <td>0.121084</td>
#     </tr>
#     <tr>
#       <td>catalysis</td>
#       <td>biodiesel</td>
#       <td>0.144114</td>
#       <td>0.023881</td>
#       <td>0.120234</td>
#     </tr>
#     <tr>
#       <td>pyrolysis</td>
#       <td>bio-oil</td>
#       <td>0.041804</td>
#       <td>0.150746</td>
#       <td>0.108942</td>
#     </tr>
#     <tr>
#       <td>vegetable oil</td>
#       <td>transesterification</td>
#       <td>0.080308</td>
#       <td>0.007463</td>
#       <td>0.072845</td>
#     </tr>
#     <tr>
#       <td>catalysis</td>
#       <td>ethanol</td>
#       <td>0.079208</td>
#       <td>0.010448</td>
#       <td>0.068760</td>
#     </tr>
#     <tr>
#       <td>transesterification</td>
#       <td>ethanol</td>
#       <td>0.089109</td>
#       <td>0.023881</td>
#       <td>0.065228</td>
#     </tr>
#     <tr>
#       <td>catalysis</td>
#       <td>methanol</td>
#       <td>0.061606</td>
#       <td>0.001493</td>
#       <td>0.060114</td>
#     </tr>
#     <tr>
#       <td>anaerobic digestion</td>
#       <td>ethanol</td>
#       <td>0.008801</td>
#       <td>0.067164</td>
#       <td>0.058363</td>
#     </tr>
#     <tr>
#       <td>gasification</td>
#       <td>syng</td>
#       <td>0.005501</td>
#       <td>0.059701</td>
#       <td>0.054201</td>
#     </tr>
#     <tr>
#       <td>vegetable oil</td>
#       <td>biodiesel</td>
#       <td>0.084708</td>
#       <td>0.032836</td>
#       <td>0.051873</td>
#     </tr>
#     <tr>
#       <td>vegetable oil</td>
#       <td>catalysis</td>
#       <td>0.063806</td>
#       <td>0.011940</td>
#       <td>0.051866</td>
#     </tr>
#     <tr>
#       <td>transesterification</td>
#       <td>methanol</td>
#       <td>0.073707</td>
#       <td>0.022388</td>
#       <td>0.051319</td>
#     </tr>
#     <tr>
#       <td>fermentation</td>
#       <td>gasoline</td>
#       <td>0.055006</td>
#       <td>0.004478</td>
#       <td>0.050528</td>
#     </tr>
#     <tr>
#       <td>pressing</td>
#       <td>ethanol</td>
#       <td>0.045105</td>
#       <td>0.002985</td>
#       <td>0.042119</td>
#     </tr>
#     <tr>
#       <td>solvents</td>
#       <td>biodiesel</td>
#       <td>0.033003</td>
#       <td>0.074627</td>
#       <td>0.041624</td>
#     </tr>
#     <tr>
#       <td>seed oil</td>
#       <td>biodiesel</td>
#       <td>0.038504</td>
#       <td>0.000000</td>
#       <td>0.038504</td>
#     </tr>
#     <tr>
#       <td>anaerobic digestion</td>
#       <td>bioethanol</td>
#       <td>0.001100</td>
#       <td>0.038806</td>
#       <td>0.037706</td>
#     </tr>
#     <tr>
#       <td>anaerobic digestion</td>
#       <td>biogas</td>
#       <td>0.167217</td>
#       <td>0.204478</td>
#       <td>0.037261</td>
#     </tr>
#   </tbody>
# </table>
# Percentages are as 0-1 in this table for easy viz.

# %% [markdown]
# With this visualization we can easily compare the term pairs and see their evolution over the course of the years.
