# %%
import py2neo
print(py2neo.__version__)
# Out:
# 4.0.0b2

# %%
# python libraries
from py2neo import Graph
import numpy as np 
from pandas import DataFrame
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import json
import math
import pandas as pd
# import plotly 
# import plotly.graph_objs as go
# import qgrid
from scipy import stats, spatial
from scipy.sparse import csr_matrix
from sklearn.cluster.bicluster import SpectralBiclustering
import scipy.spatial as sp, scipy.cluster.hierarchy as hc, scipy.sparse.csgraph as csgraph
import operator
from IPython.display import display, HTML
from matplotlib.colors import ListedColormap


# connection to Neo4j
local_connection_url = "http://localhost:7474/db/data"
connection_to_graph = Graph(local_connection_url, user="neo4j", password="zxc397") 

# plotly credentials
# plotly_config = json.load(open('plotly_config.json'))
# plotly.tools.set_credentials_file(username=plotly_config['username'], api_key=plotly_config['key'])

# %%
f_terms = list(set(DataFrame(connection_to_graph.data('MATCH (a:Asset)-[:CONTAINS]->(fs:Feedstock) RETURN  fs.term, count(a)')).as_matrix()[:, 1]))
o_terms = list(set(DataFrame(connection_to_graph.data('MATCH (a:Asset)-[:CONTAINS]->(fs:Output) RETURN  fs.term, count(a)')).as_matrix()[:, 1]))
pt_terms = list(set(DataFrame(connection_to_graph.data('MATCH (a:Asset)-[:CONTAINS]->(fs:ProcessingTech) RETURN  fs.term, count(a)')).as_matrix()[:, 1]))
bbo = list(f_terms + pt_terms + o_terms)
print ("Number of terms:", len(bbo))
nodes = bbo
print(nodes)
# Out:
# ('Number of terms:', 352)
# [u'vegetable oil', u'recycled ethanol', u'woodwaste/bagasse', u'natural gas', u'various grasses', u'nonedible oils', u'animal fats', u'paper', u'ponderosa pine', u'grass seed', u'sulfite spent liquor from spruce wood pulping', u'osb', u'paper waste', u'corn cob', u'energy grasses', u'logging residues', u'willow', u'crop waste', u'firewood', u'jatropha', u'sugarcane bagasse', u'sugar', u'durum', u'wood', u'municipal solid waste', u'banna grass', u'waste oil', u'cassava pulp', u'barley', u'mixed oilseeds', u'starch', u'white grease', u'coniferous wood', u'corn oil', u'wood waste', u'mixed cellulose', u'corn stalks', u'yellow grease', u'molasses', u'woodchips', u'food waste', u'citrus residues', u'wood chips', u'spent sulphite liquor feedstock', u'palm, rapeseed oil, waste fat', u'cotton residue', u'industrial waste', u'deciduous forests', u'corn stover', u'cereals/sugar', u'waste fat', u'waste vegetable oil', u'tallow', u'sewage', u'white pine', u'hardwood', u'biogas from municipal wastewater treatment facility digesters', u'loblolly pine', u'stump material', u'miscanthus', u'palm', u'milo', u'animal residue', u'bark', u'fall rye', u'agriculture', u'textiles', u'beef tallow', u'animal waste', u'cobs', u'forest residues', u'grass clippings', u'fat products', u'plywood', u'dry biomass', u'southern yellow pine', u'free fatty acid', u'trap grease', u'woody and agricultural by-products', u'syngas from gasifier', u'cellulose', u'wheat', u'organic waste', u'oil plants', u'corn', u'animal manure', u'dung', u'agricultural waste', u'elephant grass', u'soft white spring wheat', u'biogas from landfills', u'mixed grass', u'waste water sludge', u'poppy seed', u'algae', u'rice straw', u'barley straw', u'Giant reed', u'rice hulls', u'canola oil', u'msw', u'digester gas', u'seeds', u'grain', u'distillers grain', u'sugar beet', u'mixed biomass', u'corn stover, cobs', u'brewery waste', u'triticale', u'camelina', u'cellulosic biomass', u'multi feedstock', u'plastics', u'palm stearin', u'poultry fat', u'straw', u'water hyacinth', u'mixedwood', u'hogs', u'beverage waste', u'macroalgae', u'sugar base', u'soy', u'woody biomass', u'maple', u'bagasse', u'wheat straw', u'jathropa', u'medium density fiberboard', u'biodegradable waste', u'corn sugar', u'poplar/energy woods', u'husk', u'fog', u'feed wheat', u'waste', u'soy oil', u'oilseeds', u'pal waste', u'grass straw and corn stalks', u'agricultural biomass', u'glycerin', u'used cooking oil', u'hydrous ethanol', u'seed oil', u'manure', u'shrub willow', u'juncea oil', u'grains', u'syngas', u'barley starch', u'particle board', u'energy crops', u'slash pine', u'lemna', u'lumber', u'hog fuel', u'Decommissioned electricity poles and railway ties', u'agricultural residues', u'grass', u'sorghum', u'virgin oil', u'cps wheat', u'rapeseed oil', u'cooking oil', u'sawdust', u'sugarcane trash', u'radiate pine', u'cheese whey', u'red pine', u'corn/barley', u'switchgrass', u'yard trimmings', u'stover', u'biogenic waste oils', u'douglas fir', u'bagasse/cane trash', u'crude glycerine', u'brown grease', u'waste water', u'garden waste', u'wood processing residues', u'yeast', u'oak', u'pine', u'natural fats', u'forestry', u'wood fuel', u'rice straw, corn stalks', u'steel waste gas (co)', u'mixed prairie grass', u'whey', u'lignocellulosics', u'cellulosic sugars', u'juniper', u'mixed biomass, natural gas', u'sugarcane', u'urban wood', u'flaxseed oil', u'residues', u'cotton gin trash', u'rapeseed', u'arundo donax', u'dedicated energy crops', u'black liquor', u'eucalyptus', u'corn/milo', u'beets', u'non-food grade canola oil', u'non-cellulosic portions of sfw', u'refined vegetable oil', u'vegetable waste', u'poplar', u'palm oil', u'blend', u'hybrid poplar', u'hydrochloric acid', u'algae transesterification', u' aerobic digestion', u'consolidated bioprocessing', u'methane recovery', u'hydroprocessing', u'solar conversion', u'biomass combustion', u'gasification', u'enzymatic hydrolysis', u'biogas productions', u'chemprocessing', u' ...

# %%
#Remove leading spaces
newnodes = list()
for node in nodes:
    newnode = node.lstrip()
    newnodes.append(newnode)
nodes=newnodes
nodes
# Out:
# [u'vegetable oil',
#  u'recycled ethanol',
#  u'woodwaste/bagasse',
#  u'natural gas',
#  u'various grasses',
#  u'nonedible oils',
#  u'animal fats',
#  u'paper',
#  u'ponderosa pine',
#  u'grass seed',
#  u'sulfite spent liquor from spruce wood pulping',
#  u'osb',
#  u'paper waste',
#  u'corn cob',
#  u'energy grasses',
#  u'logging residues',
#  u'willow',
#  u'crop waste',
#  u'firewood',
#  u'jatropha',
#  u'sugarcane bagasse',
#  u'sugar',
#  u'durum',
#  u'wood',
#  u'municipal solid waste',
#  u'banna grass',
#  u'waste oil',
#  u'cassava pulp',
#  u'barley',
#  u'mixed oilseeds',
#  u'starch',
#  u'white grease',
#  u'coniferous wood',
#  u'corn oil',
#  u'wood waste',
#  u'mixed cellulose',
#  u'corn stalks',
#  u'yellow grease',
#  u'molasses',
#  u'woodchips',
#  u'food waste',
#  u'citrus residues',
#  u'wood chips',
#  u'spent sulphite liquor feedstock',
#  u'palm, rapeseed oil, waste fat',
#  u'cotton residue',
#  u'industrial waste',
#  u'deciduous forests',
#  u'corn stover',
#  u'cereals/sugar',
#  u'waste fat',
#  u'waste vegetable oil',
#  u'tallow',
#  u'sewage',
#  u'white pine',
#  u'hardwood',
#  u'biogas from municipal wastewater treatment facility digesters',
#  u'loblolly pine',
#  u'stump material',
#  u'miscanthus',
#  u'palm',
#  u'milo',
#  u'animal residue',
#  u'bark',
#  u'fall rye',
#  u'agriculture',
#  u'textiles',
#  u'beef tallow',
#  u'animal waste',
#  u'cobs',
#  u'forest residues',
#  u'grass clippings',
#  u'fat products',
#  u'plywood',
#  u'dry biomass',
#  u'southern yellow pine',
#  u'free fatty acid',
#  u'trap grease',
#  u'woody and agricultural by-products',
#  u'syngas from gasifier',
#  u'cellulose',
#  u'wheat',
#  u'organic waste',
#  u'oil plants',
#  u'corn',
#  u'animal manure',
#  u'dung',
#  u'agricultural waste',
#  u'elephant grass',
#  u'soft white spring wheat',
#  u'biogas from landfills',
#  u'mixed grass',
#  u'waste water sludge',
#  u'poppy seed',
#  u'algae',
#  u'rice straw',
#  u'barley straw',
#  u'Giant reed',
#  u'rice hulls',
#  u'canola oil',
#  u'msw',
#  u'digester gas',
#  u'seeds',
#  u'grain',
#  u'distillers grain',
#  u'sugar beet',
#  u'mixed biomass',
#  u'corn stover, cobs',
#  u'brewery waste',
#  u'triticale',
#  u'camelina',
#  u'cellulosic biomass',
#  u'multi feedstock',
#  u'plastics',
#  u'palm stearin',
#  u'poultry fat',
#  u'straw',
#  u'water hyacinth',
#  u'mixedwood',
#  u'hogs',
#  u'beverage waste',
#  u'macroalgae',
#  u'sugar base',
#  u'soy',
#  u'woody biomass',
#  u'maple',
#  u'bagasse',
#  u'wheat straw',
#  u'jathropa',
#  u'medium density fiberboard',
#  u'biodegradable waste',
#  u'corn sugar',
#  u'poplar/energy woods',
#  u'husk',
#  u'fog',
#  u'feed wheat',
#  u'waste',
#  u'soy oil',
#  u'oilseeds',
#  u'pal waste',
#  u'grass straw and corn stalks',
#  u'agricultural biomass',
#  u'glycerin',
#  u'used cooking oil',
#  u'hydrous ethanol',
#  u'seed oil',
#  u'manure',
#  u'shrub willow',
#  u'juncea oil',
#  u'grains',
#  u'syngas',
#  u'barley starch',
#  u'particle board',
#  u'energy crops',
#  u'slash pine',
#  u'lemna',
#  u'lumber',
#  u'hog fuel',
#  u'Decommissioned electricity poles and railway ties',
#  u'agricultural residues',
#  u'grass',
#  u'sorghum',
#  u'virgin oil',
#  u'cps wheat',
#  u'rapeseed oil',
#  u'cooking oil',
#  u'sawdust',
#  u'sugarcane trash',
#  u'radiate pine',
#  u'cheese whey',
#  u'red pine',
#  u'corn/barley',
#  u'switchgrass',
#  u'yard trimmings',
#  u'stover',
#  u'biogenic waste oils',
#  u'douglas fir',
#  u'bagasse/cane trash',
#  u'crude glycerine',
#  u'brown grease',
#  u'waste water',
#  u'garden waste',
#  u'wood processing residues',
#  u'yeast',
#  u'oak',
#  u'pine',
#  u'natural fats',
#  u'forestry',
#  u'wood fuel',
#  u'rice straw, corn stalks',
#  u'steel waste gas (co)',
#  u'mixed prairie grass',
#  u'whey',
#  u'lignocellulosics',
#  u'cellulosic sugars',
#  u'juniper',
#  u'mixed biomass, natural gas',
#  u'sugarcane',
#  u'urban wood',
#  u'flaxseed oil',
#  u'residues',
#  u'cotton gin trash',
#  u'rapeseed',
#  u'arundo donax',
#  u'dedicated energy crops',
#  u'black liquor',
#  u'eucalyptus',
#  u'corn/milo',
#  u'beets',
#  u'non-food grade canola oil',
#  u'non-cellulosic portions of sfw',
#  u'refined vegetable oil',
#  u'vegetable waste',
#  u'poplar',
#  u'palm oil',
#  u'blend',
#  u'hybrid poplar',
#  u'hydrochloric acid',
#  u'algae transesterification',
#  u'aerobic digestion',
#  u'consolidated bioprocessing',
#  u'methane recovery',
#  u'hydroprocessing',
#  u'solar conversion',
#  u'biomass combustion',
#  u'gasification',
#  u'enzymatic hydrolysis',
#  u'biogas productions',
#  u'chemprocessing',
#  u'oil extraction',
#  u'bioenergy generation',
#  u'coking',
#  u'orc process',
#  u'charring',
#  u'cbp',
#  u'microwave',
#  u'btl - syngas',
#  u'bioforming',
#  u'algal oil extraction',
#  u'methanol synthesis, mtg catalysis',
#  u'biomass gasification',
#  u'black liquor gasification',
#  u'grate furnaces',
#  u'algae burning/transesterifcation',
#  u'solvents',
#  u'fixed bed gasifiers',
#  u'biochemical conversions',
#  u'blg',
#  u'alcoholic fermentation',
#  u'steam reform/ft',
#  u'fischer-tropsch',
#  u'hydrotreating',
#  u'transesterification',
#  u'algae oil extraction',
#  u'gas cleaning',
#  u'landfill gas',
#  u'pyrolysis oil',
#  u'thermochemical conversions',
#  u'fast pyrolysis',
#  u'scrubbers',
#  u'tbd',
#  u'plant cell culture',
#  u'acid hydrolysis',
#  u'advanced fermentation',
#  u'pyrolysis',
#  u'liquefaction',
#  u'gasification-fermentation',
#  u'hydrolysis',
#  u'algae oil hydrotreating',
#  u'ft microchannel reactor',
#  u'pressing',
#  u'metathesis',
#  u'algae fermentation',
#  u'fluidized bed furnaces',
#  u'anaerobic digestion',
#  u'ti gasification',
#  u'fermentation',
#  u'catalysis',
#  u'renewable liquefied natural gas',
#  u'furanics',
#  u'biodme',
#  u'chems',
#  u'cellulosic heating oil',
#  u'chems, fibers',
#  u'succinic acid',
#  u'renewable jet fuel',
#  u'succinic acid, polylutylene succinate',
#  u'papaya to fatty acids',
#  u'ethanol blending',
#  u'succinic acid/ bdo',
#  u'adipic acid',
#  u'renewable chemicals',
#  u'cellulosic naphtha',
#  u'syng',
#  u'drop-in fuels',
#  u'pla from cassava',
#  u'electricity from biomass',
#  u'renewable heating oil',
#  u'bioplastic',
#  u'biobutanol',
#  u'ester renewable diesel',
#  u'eth from bagasse',
#  u'bioieselethanolanol',
#  u'cellulosic renewable gasoline',
#  u'advanced biofuel',
#  u'renewable electricity',
#  u'renewable gasoline',
#  u'celleth from bagasse',
#  u'methanol',
#  u'biogas',
#  u'cellulosic ethanol',
#  u'bdo',
#  u'biodieseliesel',
#  u'nutriceuticals',
#  u'butanol',
#  u'biopolymers',
#  u'sng',
#  u'bio-oil',
#  u'biofuels from algae',
#  u'cellulosic biofuel',
#  u'biofene',
#  u'celleth from wheat straw',
#  u'biodiesel',
#  u'cellulosic renewable gasoline blendstock',
#  u'biogasoline',
#  u'lpg',
#  u'renewable diesel',
#  u'naphtha',
#  u'ethanol',
#  u'cellulosic diesel',
#  u'methanol/then ethanol',
#  u'biodiesel bioethanol',
#  u'fatty acid ethyl ester',
#  u'rdif',
#  u'polyethylene',
#  u'biodiesel blending',
#  u'bioresin',
#  u'bioethanol',
#  u'bioplymers from corn, potatoes, tapioca',
#  u'biofuels for transport',
#  u'mixed alcohol fuels',
#  u'gasoline',
#  u'ethanolanol',
#  u'renewable fuel',
#  u'pdo',
#  u'biobdo',
#  u'renewable diesel from animal fats, veggie oils',
#  u'renewable jet',
#  u'renewable oils',
#  u'pellets',
#  u'renewable compressed natural gas',
#  u'biomass-based diesel']

# %%
#REMOVAL/ADDITION - find nodes with commas, separate them and add to nodelist if not in there, remove the unseparated node
print len(nodes)
for node in nodes:
    if "," in node:
        separates = node.split(",")
        for separate in separates:
            #remove leading space if any
            separate = separate.lstrip()
            if separate not in nodes:
                nodes.append(separate)
                print separate
        #remove unseparated node from list
        nodes.remove(node)
print len(nodes)
print nodes
# Out:
# 352
# methanol synthesis
# mtg catalysis
# fibers
# polylutylene succinate
# bioplymers from corn
# potatoes
# tapioca
# renewable diesel from animal fats
# veggie oils
# 352
# [u'vegetable oil', u'recycled ethanol', u'woodwaste/bagasse', u'natural gas', u'various grasses', u'nonedible oils', u'animal fats', u'paper', u'ponderosa pine', u'grass seed', u'sulfite spent liquor from spruce wood pulping', u'osb', u'paper waste', u'corn cob', u'energy grasses', u'logging residues', u'willow', u'crop waste', u'firewood', u'jatropha', u'sugarcane bagasse', u'sugar', u'durum', u'wood', u'municipal solid waste', u'banna grass', u'waste oil', u'cassava pulp', u'barley', u'mixed oilseeds', u'starch', u'white grease', u'coniferous wood', u'corn oil', u'wood waste', u'mixed cellulose', u'corn stalks', u'yellow grease', u'molasses', u'woodchips', u'food waste', u'citrus residues', u'wood chips', u'spent sulphite liquor feedstock', u'cotton residue', u'industrial waste', u'deciduous forests', u'corn stover', u'cereals/sugar', u'waste fat', u'waste vegetable oil', u'tallow', u'sewage', u'white pine', u'hardwood', u'biogas from municipal wastewater treatment facility digesters', u'loblolly pine', u'stump material', u'miscanthus', u'palm', u'milo', u'animal residue', u'bark', u'fall rye', u'agriculture', u'textiles', u'beef tallow', u'animal waste', u'cobs', u'forest residues', u'grass clippings', u'fat products', u'plywood', u'dry biomass', u'southern yellow pine', u'free fatty acid', u'trap grease', u'woody and agricultural by-products', u'syngas from gasifier', u'cellulose', u'wheat', u'organic waste', u'oil plants', u'corn', u'animal manure', u'dung', u'agricultural waste', u'elephant grass', u'soft white spring wheat', u'biogas from landfills', u'mixed grass', u'waste water sludge', u'poppy seed', u'algae', u'rice straw', u'barley straw', u'Giant reed', u'rice hulls', u'canola oil', u'msw', u'digester gas', u'seeds', u'grain', u'distillers grain', u'sugar beet', u'mixed biomass', u'brewery waste', u'triticale', u'camelina', u'cellulosic biomass', u'multi feedstock', u'plastics', u'palm stearin', u'poultry fat', u'straw', u'water hyacinth', u'mixedwood', u'hogs', u'beverage waste', u'macroalgae', u'sugar base', u'soy', u'woody biomass', u'maple', u'bagasse', u'wheat straw', u'jathropa', u'medium density fiberboard', u'biodegradable waste', u'corn sugar', u'poplar/energy woods', u'husk', u'fog', u'feed wheat', u'waste', u'soy oil', u'oilseeds', u'pal waste', u'grass straw and corn stalks', u'agricultural biomass', u'glycerin', u'used cooking oil', u'hydrous ethanol', u'seed oil', u'manure', u'shrub willow', u'juncea oil', u'grains', u'syngas', u'barley starch', u'particle board', u'energy crops', u'slash pine', u'lemna', u'lumber', u'hog fuel', u'Decommissioned electricity poles and railway ties', u'agricultural residues', u'grass', u'sorghum', u'virgin oil', u'cps wheat', u'rapeseed oil', u'cooking oil', u'sawdust', u'sugarcane trash', u'radiate pine', u'cheese whey', u'red pine', u'corn/barley', u'switchgrass', u'yard trimmings', u'stover', u'biogenic waste oils', u'douglas fir', u'bagasse/cane trash', u'crude glycerine', u'brown grease', u'waste water', u'garden waste', u'wood processing residues', u'yeast', u'oak', u'pine', u'natural fats', u'forestry', u'wood fuel', u'steel waste gas (co)', u'mixed prairie grass', u'whey', u'lignocellulosics', u'cellulosic sugars', u'juniper', u'sugarcane', u'urban wood', u'flaxseed oil', u'residues', u'cotton gin trash', u'rapeseed', u'arundo donax', u'dedicated energy crops', u'black liquor', u'eucalyptus', u'corn/milo', u'beets', u'non-food grade canola oil', u'non-cellulosic portions of sfw', u'refined vegetable oil', u'vegetable waste', u'poplar', u'palm oil', u'blend', u'hybrid poplar', u'hydrochloric acid', u'algae transesterification', u'aerobic digestion', u'consolidated bioprocessing', u'methane recovery', u'hydroprocessing', u'solar conversion', u'biomass combustion', u'gasification', u'enzymatic hydrolysis', u'biogas productions', u'chemprocessing', u'oil extraction', u'bioenergy generation', u'coking', u'orc process', u'charring', u'cbp', u'microwave', u'btl - syng ...

# %%
destfile = open('nodesdump.txt', 'w')
json.dump(nodes, destfile)
destfile.close()

# %%
with open('nodesdump.txt') as f:
    nodes = json.load(f)
getnodes
# Out:
# [u'vegetable oil',
#  u'recycled ethanol',
#  u'woodwaste/bagasse',
#  u'natural gas',
#  u'various grasses',
#  u'nonedible oils',
#  u'animal fats',
#  u'paper',
#  u'ponderosa pine',
#  u'grass seed',
#  u'sulfite spent liquor from spruce wood pulping',
#  u'osb',
#  u'paper waste',
#  u'corn cob',
#  u'energy grasses',
#  u'logging residues',
#  u'willow',
#  u'crop waste',
#  u'firewood',
#  u'jatropha',
#  u'sugarcane bagasse',
#  u'sugar',
#  u'durum',
#  u'wood',
#  u'municipal solid waste',
#  u'banna grass',
#  u'waste oil',
#  u'cassava pulp',
#  u'barley',
#  u'mixed oilseeds',
#  u'starch',
#  u'white grease',
#  u'coniferous wood',
#  u'corn oil',
#  u'wood waste',
#  u'mixed cellulose',
#  u'corn stalks',
#  u'yellow grease',
#  u'molasses',
#  u'woodchips',
#  u'food waste',
#  u'citrus residues',
#  u'wood chips',
#  u'spent sulphite liquor feedstock',
#  u'cotton residue',
#  u'industrial waste',
#  u'deciduous forests',
#  u'corn stover',
#  u'cereals/sugar',
#  u'waste fat',
#  u'waste vegetable oil',
#  u'tallow',
#  u'sewage',
#  u'white pine',
#  u'hardwood',
#  u'biogas from municipal wastewater treatment facility digesters',
#  u'loblolly pine',
#  u'stump material',
#  u'miscanthus',
#  u'palm',
#  u'milo',
#  u'animal residue',
#  u'bark',
#  u'fall rye',
#  u'agriculture',
#  u'textiles',
#  u'beef tallow',
#  u'animal waste',
#  u'cobs',
#  u'forest residues',
#  u'grass clippings',
#  u'fat products',
#  u'plywood',
#  u'dry biomass',
#  u'southern yellow pine',
#  u'free fatty acid',
#  u'trap grease',
#  u'woody and agricultural by-products',
#  u'syngas from gasifier',
#  u'cellulose',
#  u'wheat',
#  u'organic waste',
#  u'oil plants',
#  u'corn',
#  u'animal manure',
#  u'dung',
#  u'agricultural waste',
#  u'elephant grass',
#  u'soft white spring wheat',
#  u'biogas from landfills',
#  u'mixed grass',
#  u'waste water sludge',
#  u'poppy seed',
#  u'algae',
#  u'rice straw',
#  u'barley straw',
#  u'Giant reed',
#  u'rice hulls',
#  u'canola oil',
#  u'msw',
#  u'digester gas',
#  u'seeds',
#  u'grain',
#  u'distillers grain',
#  u'sugar beet',
#  u'mixed biomass',
#  u'brewery waste',
#  u'triticale',
#  u'camelina',
#  u'cellulosic biomass',
#  u'multi feedstock',
#  u'plastics',
#  u'palm stearin',
#  u'poultry fat',
#  u'straw',
#  u'water hyacinth',
#  u'mixedwood',
#  u'hogs',
#  u'beverage waste',
#  u'macroalgae',
#  u'sugar base',
#  u'soy',
#  u'woody biomass',
#  u'maple',
#  u'bagasse',
#  u'wheat straw',
#  u'jathropa',
#  u'medium density fiberboard',
#  u'biodegradable waste',
#  u'corn sugar',
#  u'poplar/energy woods',
#  u'husk',
#  u'fog',
#  u'feed wheat',
#  u'waste',
#  u'soy oil',
#  u'oilseeds',
#  u'pal waste',
#  u'grass straw and corn stalks',
#  u'agricultural biomass',
#  u'glycerin',
#  u'used cooking oil',
#  u'hydrous ethanol',
#  u'seed oil',
#  u'manure',
#  u'shrub willow',
#  u'juncea oil',
#  u'grains',
#  u'syngas',
#  u'barley starch',
#  u'particle board',
#  u'energy crops',
#  u'slash pine',
#  u'lemna',
#  u'lumber',
#  u'hog fuel',
#  u'Decommissioned electricity poles and railway ties',
#  u'agricultural residues',
#  u'grass',
#  u'sorghum',
#  u'virgin oil',
#  u'cps wheat',
#  u'rapeseed oil',
#  u'cooking oil',
#  u'sawdust',
#  u'sugarcane trash',
#  u'radiate pine',
#  u'cheese whey',
#  u'red pine',
#  u'corn/barley',
#  u'switchgrass',
#  u'yard trimmings',
#  u'stover',
#  u'biogenic waste oils',
#  u'douglas fir',
#  u'bagasse/cane trash',
#  u'crude glycerine',
#  u'brown grease',
#  u'waste water',
#  u'garden waste',
#  u'wood processing residues',
#  u'yeast',
#  u'oak',
#  u'pine',
#  u'natural fats',
#  u'forestry',
#  u'wood fuel',
#  u'steel waste gas (co)',
#  u'mixed prairie grass',
#  u'whey',
#  u'lignocellulosics',
#  u'cellulosic sugars',
#  u'juniper',
#  u'sugarcane',
#  u'urban wood',
#  u'flaxseed oil',
#  u'residues',
#  u'cotton gin trash',
#  u'rapeseed',
#  u'arundo donax',
#  u'dedicated energy crops',
#  u'black liquor',
#  u'eucalyptus',
#  u'corn/milo',
#  u'beets',
#  u'non-food grade canola oil',
#  u'non-cellulosic portions of sfw',
#  u'refined vegetable oil',
#  u'vegetable waste',
#  u'poplar',
#  u'palm oil',
#  u'blend',
#  u'hybrid poplar',
#  u'hydrochloric acid',
#  u'algae transesterification',
#  u'aerobic digestion',
#  u'consolidated bioprocessing',
#  u'methane recovery',
#  u'hydroprocessing',
#  u'solar conversion',
#  u'biomass combustion',
#  u'gasification',
#  u'enzymatic hydrolysis',
#  u'biogas productions',
#  u'chemprocessing',
#  u'oil extraction',
#  u'bioenergy generation',
#  u'coking',
#  u'orc process',
#  u'charring',
#  u'cbp',
#  u'microwave',
#  u'btl - syngas',
#  u'bioforming',
#  u'algal oil extraction',
#  u'biomass gasification',
#  u'black liquor gasification',
#  u'grate furnaces',
#  u'algae burning/transesterifcation',
#  u'solvents',
#  u'fixed bed gasifiers',
#  u'biochemical conversions',
#  u'blg',
#  u'alcoholic fermentation',
#  u'steam reform/ft',
#  u'fischer-tropsch',
#  u'hydrotreating',
#  u'transesterification',
#  u'algae oil extraction',
#  u'gas cleaning',
#  u'landfill gas',
#  u'pyrolysis oil',
#  u'thermochemical conversions',
#  u'fast pyrolysis',
#  u'scrubbers',
#  u'tbd',
#  u'plant cell culture',
#  u'acid hydrolysis',
#  u'advanced fermentation',
#  u'pyrolysis',
#  u'liquefaction',
#  u'gasification-fermentation',
#  u'hydrolysis',
#  u'algae oil hydrotreating',
#  u'ft microchannel reactor',
#  u'pressing',
#  u'metathesis',
#  u'algae fermentation',
#  u'fluidized bed furnaces',
#  u'anaerobic digestion',
#  u'ti gasification',
#  u'fermentation',
#  u'catalysis',
#  u'renewable liquefied natural gas',
#  u'furanics',
#  u'biodme',
#  u'chems',
#  u'cellulosic heating oil',
#  u'succinic acid',
#  u'renewable jet fuel',
#  u'papaya to fatty acids',
#  u'ethanol blending',
#  u'succinic acid/ bdo',
#  u'adipic acid',
#  u'renewable chemicals',
#  u'cellulosic naphtha',
#  u'syng',
#  u'drop-in fuels',
#  u'pla from cassava',
#  u'electricity from biomass',
#  u'renewable heating oil',
#  u'bioplastic',
#  u'biobutanol',
#  u'ester renewable diesel',
#  u'eth from bagasse',
#  u'bioieselethanolanol',
#  u'cellulosic renewable gasoline',
#  u'advanced biofuel',
#  u'renewable electricity',
#  u'renewable gasoline',
#  u'celleth from bagasse',
#  u'methanol',
#  u'biogas',
#  u'cellulosic ethanol',
#  u'bdo',
#  u'biodieseliesel',
#  u'nutriceuticals',
#  u'butanol',
#  u'biopolymers',
#  u'sng',
#  u'bio-oil',
#  u'biofuels from algae',
#  u'cellulosic biofuel',
#  u'biofene',
#  u'celleth from wheat straw',
#  u'biodiesel',
#  u'cellulosic renewable gasoline blendstock',
#  u'biogasoline',
#  u'lpg',
#  u'renewable diesel',
#  u'naphtha',
#  u'ethanol',
#  u'cellulosic diesel',
#  u'methanol/then ethanol',
#  u'biodiesel bioethanol',
#  u'fatty acid ethyl ester',
#  u'rdif',
#  u'polyethylene',
#  u'biodiesel blending',
#  u'bioresin',
#  u'bioethanol',
#  u'biofuels for transport',
#  u'mixed alcohol fuels',
#  u'gasoline',
#  u'ethanolanol',
#  u'renewable fuel',
#  u'pdo',
#  u'biobdo',
#  u'renewable jet',
#  u'renewable oils',
#  u'pellets',
#  u'renewable compressed natural gas',
#  u'biomass-based diesel',
#  u'methanol synthesis',
#  u'mtg catalysis',
#  u'fibers',
#  u'polylutylene succinate',
#  u'bioplymers from corn',
#  u'potatoes',
#  u'tapioca',
#  u'renewable diesel from animal fats',
#  u'veggie oils']

# %%
#REMOVAL - all edges with NULL Years
feedproc = connection_to_graph.data('MATCH p2=(feed:Feedstock)<-[:CONTAINS]-(n:Asset)-[:CONTAINS]->(proc:ProcessingTech) WHERE (n.year)<>"Null" RETURN n.id, n.year, feed.term, proc.term')
feedout = connection_to_graph.data('MATCH p2=(feed:Feedstock)<-[:CONTAINS]-(n:Asset)-[:CONTAINS]->(out:Output) WHERE (n.year)<>"Null" RETURN n.id, n.year, feed.term, out.term')
procout = connection_to_graph.data('MATCH p2=(proc:ProcessingTech)<-[:CONTAINS]-(n:Asset)-[:CONTAINS]->(out:Output) WHERE (n.year)<>"Null" RETURN n.id, n.year, proc.term, out.term')
df1 = pd.DataFrame(feedproc)
df2 = pd.DataFrame(feedout)
df3 = pd.DataFrame(procout)

# %%
edgelist = []
for index, row in df1.iterrows():
    rowstr = row[u'feed.term'].lstrip() + "," + row[u'proc.term'].lstrip() + "," + row[u'n.year']
    #edgelist = edgelist + str
    edgelist.append(rowstr)
# print "df2-------------"
for index, row in df2.iterrows():
    rowstr = row[u'feed.term'].lstrip() + "," + row[u'out.term'].lstrip() + "," + row[u'n.year']
    edgelist.append(rowstr)
    #edgelist = edgelist + str
# print "df3-------------"
for index, row in df3.iterrows():
    rowstr = row[u'proc.term'].lstrip() + "," + row[u'out.term'].lstrip() + "," + row[u'n.year']
    edgelist.append(rowstr)
    #edgelist = edgelist + str
edgelist

# %%
import csv

with open('edgelist', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(edgelist)

# %%
df = pd.DataFrame({'edges':edgelist}) #convert list to dataframe

# %%
# convert into weighted edgelist - count occurences for each edge
df['source'], df['target'], df['year'] = df['edges'].str.split(',', 2).str
weighted = df.groupby(['edges','source','target','year']).size().reset_index(name='count')
#weightedless = df.groupby(['edges']).size().reset_index(name='count')
#weightedless
weighted

# %%
#TODO - REWRITE THIS AS FOR ONE YEAR
#REMOVAL - remove nodes from nodelist that are not in edges
print len(nodes)
toremove = []
for node in nodes:
    i = 0
    #check if node is in source
    for source in df['source']:
        if node == source:
            i = 1
    #check if node is in source
    for target in df['target']:
        if node == target:
            i = 1
    if i == 0:
        toremove.append(node)
        nodes.remove(node)
print (toremove)
print (len(nodes))

# %%
#nodeindex = {0:'zero',1:'one'}
#create dictionary to map indexes to nodes
nodeindex = {}
for i in range(len(nodes)):
    nodeindex[i] = nodes[i]
nodeindex

# %%
# create matrix with zeros with size nodes x nodes
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
zero_data = np.zeros(shape=(len(nodes),len(nodes)))
adjacency = pd.DataFrame(zero_data, index = nodeindex, columns=nodes)
adjacency.rename(index=nodeindex, inplace=True)
#d.rename(nodes, axis='index')
#dists.at[' aerobic digestion',' aerobic digestion'] = 1

# %%
if "anaerobic digestion" in nodes:
    print "yes"
else:
    print "no"

# %%
#fill adjacency matrix with actual distances, i.e. edge weights
#for each row in edgelist df 
    #put count into source/target cell in distmatrix / d.at[nodes.index(source),target] = count
for index, row in weighted.iterrows():
    #if nodes.isin(row.source) and nodes.isin(row.target) :
    #print row['count']
    if row.source in nodes and row.target in nodes:
        adjacency.at[row.source,row.target] = row['count']
        adjacency.at[row.target,row.source] = row['count']
    else:
        print (row.source + ":" + row.target)
# %store adjacency
# %store nodes

# %%
#restore clustering from iGraph
#x['a'] = 1
# %store -r clusts
clusts_nodes = dict()
for i, cluster in enumerate(clusts):
#     print ("Cluster: " + str(i))
#     print ("Size: " + str(len(cluster)))
    cnodes = list()
    for item in cluster:
        #print(nodes[item])
        #add node names to cluster
        cnodes.append(nodes[item])
    #print ("\n")
    clusts_nodes[i]=cnodes
#print# clusts_nodes

# %%
#swap keys with values
nodesdict = dict()
for key, values in clusts_nodes.iteritems():
    for value in values:
        nodesdict[value] = key
#nodesdict

# %%
col_names =  ['year', 'node', 'count','clusterID']
my_df  = pd.DataFrame(columns = col_names)
my_df

# %%
for index, row in weighted.iterrows():
        my_df.loc[len(my_df)] = [row.year, row.source, row['count'], nodesdict[row.source.lstrip()]]
        my_df.loc[len(my_df)] = [row.year, row.target, row['count'], nodesdict[row.target.lstrip()]]
#my_df

# %%
for index, row in my_df.iterrows():
    #REMOVE node occurences where year is not correct - 21 rows
    if len(row.year)<>4:
        print row.year
        my_df.drop(index, inplace=True)
#my_df

# %%
#total = my_df.groupby(['year','clusterID','node']).sum()
total = my_df.groupby(['year','clusterID','node'], as_index=False, group_keys=False).sum()
total.head(30)

# %% [markdown]
# ## Write treemap structure to JSONs

# %%
strtotal = '{\n"name":"treemap",\n"children": [\n{'
prevyear = ''
prevcluster = ''
clID = list()
for index, row in total.iterrows():
        #print str(row.clusterID).split('\n')[0][0]
        clID = str(row.clusterID).split('\n')[0]
        #print clID
        if row.year <> prevyear:
            #new year row
            if index > 0:
                strtotal = strtotal +'\t]\n\t}\n\t]\n\t},\n\t{\n'
            strtotal = strtotal + '"name":"' + str(row.year) + '",\n'
            strtotal = strtotal + '"children": [\n{'
            if str(clID) <> prevcluster:
                #new cluster row
                strtotal = strtotal + '\t"name":"' + str(clID) + '",\n'
                strtotal = strtotal + '\t"children": [\n'
                strtotal = strtotal + '\t\t{"name":"' + row.node + '","size":' + str(row['count']) + '}'
        else:
            if str(clID) <> prevcluster:
                #new cluster row
                strtotal = strtotal +'\t]\n\t},\n\t{\n'
                strtotal = strtotal + '\t"name":"' + str(clID) + '",\n'
                strtotal = strtotal + '\t"children": [\n'
                strtotal = strtotal + '\t\t{"name":"' + row.node + '","size":' + str(row['count']) + '}'
            if clID == prevcluster:
                strtotal = strtotal + ',\n\t\t{"name":"' + row.node + '","size":' + str(row['count']) + '}'
            #strtotal = strtotal + ',\n'
            #print 'yes'
        prevyear = row.year
        prevcluster = clID
strtotal = strtotal + ']\n}\n]\n}\n]\n}'
print strtotal

# %%
#variant 2 - break down years into separate json files
# strtotal = '{\n"name":"treemap",\n"children": [\n{'
prevyear = ''
prevcluster = ''
clID = list()
jsonsar = dict() #this will be an array of json strings for each treemap
year_counter = 0
for index, row in total.iterrows():
        #print str(row.clusterID).split('\n')[0][0]
        clID = str(row.clusterID).split('\n')[0]
        #print clID
        if row.year <> prevyear:
            #if new year, then store strtotal into new variable, write it to a file
            jsonsar[year_counter] = '{\n"name":"treemap",\n"children": [\n{' + strtotal + ']\n}\n]\n}\n]\n}'
            year_counter = year_counter + 1
            #reset strtotal
            strtotal = ''
#             if index > 0:
#                 strtotal = strtotal +'\t]\n\t}\n\t]\n\t},\n\t{\n'
            strtotal = strtotal + '"name":"' + str(row.year) + '",\n'
            strtotal = strtotal + '"children": [\n{'
            if str(clID) <> prevcluster:
                #new cluster row
                strtotal = strtotal + '\t"name":"' + str(clID) + '",\n'
                strtotal = strtotal + '\t"children": [\n'
                strtotal = strtotal + '\t\t{"name":"' + row.node + '","size":' + str(row['count']) + '}'
        else:
            if str(clID) <> prevcluster:
                #new cluster row
                strtotal = strtotal +'\t]\n\t},\n\t{\n'
                strtotal = strtotal + '\t"name":"' + str(clID) + '",\n'
                strtotal = strtotal + '\t"children": [\n'
                strtotal = strtotal + '\t\t{"name":"' + row.node + '","size":' + str(row['count']) + '}'
            if clID == prevcluster:
                strtotal = strtotal + ',\n\t\t{"name":"' + row.node + '","size":' + str(row['count']) + '}'
            #strtotal = strtotal + ',\n'
            #print 'yes'
        prevyear = row.year
        prevcluster = clID
        #strtotal = strtotal + ']\n}\n]\n}\n]\n}'
        #print strtotal
print jsonsar[1]
print '------------'
print jsonsar[2]
print '------------'
print jsonsar[8]

# %%
for key in jsonsar:
    filename = 'treemap_' + str(key) + '.json'
    with open(filename, "w") as text_file:
        text_file.write(jsonsar[key])

# %% [markdown]
# ## Prepare data for TimeSlider

# %%
#count total number of node occurences per each year
nodesperyear = my_df.groupby(['year'], as_index=False, group_keys=False)['count'].sum()
nodesperyear

# %%
#count total number of edges per each year
edgesperyear = weighted.groupby(['year'], as_index=False, group_keys=False)['count'].sum()

# %%
#REMOVE node occurences where year is not correct
for index, row in edgesperyear.iterrows():
    if len(row.year)<>4:
        print row.year
        edgesperyear.drop(index, inplace=True)
edgesperyear

# %%
#merge two dataframes: node occurences and edges
timeslider = pd.merge(nodesperyear, edgesperyear, on='year')
#rename resulting columns
timeslider.rename(columns={'count_x': 'nodes', 'count_y': 'edges'}, inplace=True)
timeslider

# %%
#find delta for each year
deltatimeslider = timeslider
prevnode = 0
prevedge = 0
deltanode = 0
deltaedges = 0
for index, row in timeslider.iterrows():
    #find delta, set this delta to deltadf
    #first, lets do nodes
    deltanode = int(row.nodes) - prevnode
    deltatimeslider.loc[deltatimeslider.index[index], 'nodes'] = deltanode
    prevnode = int(row.nodes)
    #print index, deltanode
    #same for edges
    deltaedge = int(row.edges) - prevedge
    deltatimeslider.loc[deltatimeslider.index[index], 'edges'] = deltaedge
    prevedge = int(row.edges)
    #print index, deltaedge
deltatimeslider

# %%
deltatimeslider.to_csv('timeslider.csv', sep=';')

# %% [markdown]
# ## Extract one year

# %%
tempyear = '2006'
oneyear = weighted.loc[weighted['year'] == tempyear]
oneyear
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6571058431f6> in <module>()
#       1 tempyear = '2006'
# ----> 2 oneyear = weighted.loc[weighted['year'] == tempyear]
#       3 oneyear
#
# NameError: name 'weighted' is not defined

# %%
#construct list of terms that are in the edges
sourcestargets = list()
for row in oneyear.iterrows():
    #print row[1].source
    #print row[1].target
    if row[1].source not in sourcestargets:
        sourcestargets.append(row[1].source)
    if row[1].target not in sourcestargets:
        sourcestargets.append(row[1].target)
yearnodes = sourcestargets
yearnodes
# Out:
# [u'agricultural residues',
#  u'bio-oil',
#  u'butanol',
#  u'cellulosic ethanol',
#  u'ethanol',
#  u'fermentation',
#  u'hydrolysis',
#  u'methanol',
#  u'pyrolysis',
#  u'agricultural waste',
#  u'anaerobic digestion',
#  u'biodiesel',
#  u'biogas',
#  u'fischer-tropsch',
#  u'gasoline',
#  u'agriculture',
#  u'bioethanol',
#  u'biofuels from algae',
#  u'enzymatic hydrolysis',
#  u'fatty acid ethyl ester',
#  u'oil extraction',
#  u'pellets',
#  u'algae',
#  u'algal oil extraction',
#  u'biogasoline',
#  u'renewable fuel',
#  u'transesterification',
#  u'animal fats',
#  u'animal manure',
#  u'animal waste',
#  u'biobutanol',
#  u'arundo donax',
#  u'gasification',
#  u'bagasse',
#  u'banna grass',
#  u'bark',
#  u'fast pyrolysis',
#  u'pressing',
#  u'barley straw',
#  u'barley',
#  u'biomass gasification',
#  u'syng',
#  u'black liquor',
#  u'biodme',
#  u'blend',
#  u'bioplastic',
#  u'biopolymers',
#  u'gas cleaning',
#  u'naphtha',
#  u'catalysis',
#  u'cellulose',
#  u'cellulosic biomass',
#  u'cobs',
#  u'corn cob',
#  u'corn stalks',
#  u'corn stover',
#  u'corn',
#  u'biomass combustion',
#  u'renewable electricity',
#  u'dedicated energy crops',
#  u'digester gas',
#  u'distillers grain',
#  u'dry biomass',
#  u'energy crops',
#  u'energy grasses',
#  u'food waste',
#  u'forest residues',
#  u'forestry',
#  u'free fatty acid',
#  u'glycerin',
#  u'polyethylene',
#  u'solvents',
#  u'grain',
#  u'grains',
#  u'grass seed',
#  u'grass straw and corn stalks',
#  u'grass',
#  u'hardwood',
#  u'husk',
#  u'jatropha',
#  u'landfill gas',
#  u'lignocellulosics',
#  u'liquefaction',
#  u'macroalgae',
#  u'manure',
#  u'microwave',
#  u'msw',
#  u'natural gas',
#  u'lpg',
#  u'oak',
#  u'organic waste',
#  u'pal waste',
#  u'palm oil',
#  u'palm',
#  u'paper',
#  u'pine',
#  u'plastics',
#  u'poplar',
#  u'pyrolysis oil',
#  u'rapeseed oil',
#  u'rapeseed',
#  u'refined vegetable oil',
#  u'residues',
#  u'rice straw',
#  u'sawdust',
#  u'seed oil',
#  u'advanced biofuel',
#  u'seeds',
#  u'sewage',
#  u'sorghum',
#  u'soy',
#  u'starch',
#  u'stover',
#  u'straw',
#  u'sugar beet',
#  u'sugar',
#  u'sugarcane bagasse',
#  u'sugarcane',
#  u'switchgrass',
#  u'syngas from gasifier',
#  u'sng',
#  u'syngas',
#  u'vegetable oil',
#  u'waste vegetable oil',
#  u'waste water',
#  u'waste',
#  u'wheat straw',
#  u'wheat',
#  u'willow',
#  u'wood chips',
#  u'wood',
#  u'woody biomass',
#  u'yard trimmings',
#  u'yeast']

# %%
#check if this terms are in node list, if not - remove
for term in yearnodes:
    #print term
    if term not in nodes:
        print "term: " + term + " is removed"
        yearnodes.remove(term)
yearnodes
# Out:
# [u'agricultural residues',
#  u'bio-oil',
#  u'butanol',
#  u'cellulosic ethanol',
#  u'ethanol',
#  u'fermentation',
#  u'hydrolysis',
#  u'methanol',
#  u'pyrolysis',
#  u'agricultural waste',
#  u'anaerobic digestion',
#  u'biodiesel',
#  u'biogas',
#  u'fischer-tropsch',
#  u'gasoline',
#  u'agriculture',
#  u'bioethanol',
#  u'biofuels from algae',
#  u'enzymatic hydrolysis',
#  u'fatty acid ethyl ester',
#  u'oil extraction',
#  u'pellets',
#  u'algae',
#  u'algal oil extraction',
#  u'biogasoline',
#  u'renewable fuel',
#  u'transesterification',
#  u'animal fats',
#  u'animal manure',
#  u'animal waste',
#  u'biobutanol',
#  u'arundo donax',
#  u'gasification',
#  u'bagasse',
#  u'banna grass',
#  u'bark',
#  u'fast pyrolysis',
#  u'pressing',
#  u'barley straw',
#  u'barley',
#  u'biomass gasification',
#  u'syng',
#  u'black liquor',
#  u'biodme',
#  u'blend',
#  u'bioplastic',
#  u'biopolymers',
#  u'gas cleaning',
#  u'naphtha',
#  u'catalysis',
#  u'cellulose',
#  u'cellulosic biomass',
#  u'cobs',
#  u'corn cob',
#  u'corn stalks',
#  u'corn stover',
#  u'corn',
#  u'biomass combustion',
#  u'renewable electricity',
#  u'dedicated energy crops',
#  u'digester gas',
#  u'distillers grain',
#  u'dry biomass',
#  u'energy crops',
#  u'energy grasses',
#  u'food waste',
#  u'forest residues',
#  u'forestry',
#  u'free fatty acid',
#  u'glycerin',
#  u'polyethylene',
#  u'solvents',
#  u'grain',
#  u'grains',
#  u'grass seed',
#  u'grass straw and corn stalks',
#  u'grass',
#  u'hardwood',
#  u'husk',
#  u'jatropha',
#  u'landfill gas',
#  u'lignocellulosics',
#  u'liquefaction',
#  u'macroalgae',
#  u'manure',
#  u'microwave',
#  u'msw',
#  u'natural gas',
#  u'lpg',
#  u'oak',
#  u'organic waste',
#  u'pal waste',
#  u'palm oil',
#  u'palm',
#  u'paper',
#  u'pine',
#  u'plastics',
#  u'poplar',
#  u'pyrolysis oil',
#  u'rapeseed oil',
#  u'rapeseed',
#  u'refined vegetable oil',
#  u'residues',
#  u'rice straw',
#  u'sawdust',
#  u'seed oil',
#  u'advanced biofuel',
#  u'seeds',
#  u'sewage',
#  u'sorghum',
#  u'soy',
#  u'starch',
#  u'stover',
#  u'straw',
#  u'sugar beet',
#  u'sugar',
#  u'sugarcane bagasse',
#  u'sugarcane',
#  u'switchgrass',
#  u'syngas from gasifier',
#  u'sng',
#  u'syngas',
#  u'vegetable oil',
#  u'waste vegetable oil',
#  u'waste water',
#  u'waste',
#  u'wheat straw',
#  u'wheat',
#  u'willow',
#  u'wood chips',
#  u'wood',
#  u'woody biomass',
#  u'yard trimmings',
#  u'yeast']

# %%
#nodeindex = {0:'zero',1:'one'}
#create dictionary to map indexes to nodes
yearnodeindex = {}
for i in range(len(yearnodes)):
    yearnodeindex[i] = yearnodes[i]
yearnodeindex
# Out:
# {0: u'agricultural residues',
#  1: u'bio-oil',
#  2: u'butanol',
#  3: u'cellulosic ethanol',
#  4: u'ethanol',
#  5: u'fermentation',
#  6: u'hydrolysis',
#  7: u'methanol',
#  8: u'pyrolysis',
#  9: u'agricultural waste',
#  10: u'anaerobic digestion',
#  11: u'biodiesel',
#  12: u'biogas',
#  13: u'fischer-tropsch',
#  14: u'gasoline',
#  15: u'agriculture',
#  16: u'bioethanol',
#  17: u'biofuels from algae',
#  18: u'enzymatic hydrolysis',
#  19: u'fatty acid ethyl ester',
#  20: u'oil extraction',
#  21: u'pellets',
#  22: u'algae',
#  23: u'algal oil extraction',
#  24: u'biogasoline',
#  25: u'renewable fuel',
#  26: u'transesterification',
#  27: u'animal fats',
#  28: u'animal manure',
#  29: u'animal waste',
#  30: u'biobutanol',
#  31: u'arundo donax',
#  32: u'gasification',
#  33: u'bagasse',
#  34: u'banna grass',
#  35: u'bark',
#  36: u'fast pyrolysis',
#  37: u'pressing',
#  38: u'barley straw',
#  39: u'barley',
#  40: u'biomass gasification',
#  41: u'syng',
#  42: u'black liquor',
#  43: u'biodme',
#  44: u'blend',
#  45: u'bioplastic',
#  46: u'biopolymers',
#  47: u'gas cleaning',
#  48: u'naphtha',
#  49: u'catalysis',
#  50: u'cellulose',
#  51: u'cellulosic biomass',
#  52: u'cobs',
#  53: u'corn cob',
#  54: u'corn stalks',
#  55: u'corn stover',
#  56: u'corn',
#  57: u'biomass combustion',
#  58: u'renewable electricity',
#  59: u'dedicated energy crops',
#  60: u'digester gas',
#  61: u'distillers grain',
#  62: u'dry biomass',
#  63: u'energy crops',
#  64: u'energy grasses',
#  65: u'food waste',
#  66: u'forest residues',
#  67: u'forestry',
#  68: u'free fatty acid',
#  69: u'glycerin',
#  70: u'polyethylene',
#  71: u'solvents',
#  72: u'grain',
#  73: u'grains',
#  74: u'grass seed',
#  75: u'grass straw and corn stalks',
#  76: u'grass',
#  77: u'hardwood',
#  78: u'husk',
#  79: u'jatropha',
#  80: u'landfill gas',
#  81: u'lignocellulosics',
#  82: u'liquefaction',
#  83: u'macroalgae',
#  84: u'manure',
#  85: u'microwave',
#  86: u'msw',
#  87: u'natural gas',
#  88: u'lpg',
#  89: u'oak',
#  90: u'organic waste',
#  91: u'pal waste',
#  92: u'palm oil',
#  93: u'palm',
#  94: u'paper',
#  95: u'pine',
#  96: u'plastics',
#  97: u'poplar',
#  98: u'pyrolysis oil',
#  99: u'rapeseed oil',
#  100: u'rapeseed',
#  101: u'refined vegetable oil',
#  102: u'residues',
#  103: u'rice straw',
#  104: u'sawdust',
#  105: u'seed oil',
#  106: u'advanced biofuel',
#  107: u'seeds',
#  108: u'sewage',
#  109: u'sorghum',
#  110: u'soy',
#  111: u'starch',
#  112: u'stover',
#  113: u'straw',
#  114: u'sugar beet',
#  115: u'sugar',
#  116: u'sugarcane bagasse',
#  117: u'sugarcane',
#  118: u'switchgrass',
#  119: u'syngas from gasifier',
#  120: u'sng',
#  121: u'syngas',
#  122: u'vegetable oil',
#  123: u'waste vegetable oil',
#  124: u'waste water',
#  125: u'waste',
#  126: u'wheat straw',
#  127: u'wheat',
#  128: u'willow',
#  129: u'wood chips',
#  130: u'wood',
#  131: u'woody biomass',
#  132: u'yard trimmings',
#  133: u'yeast'}

# %%
zero_data = np.zeros(shape=(len(yearnodes),len(yearnodes)))
yearadjacency = pd.DataFrame(zero_data, index = yearnodeindex, columns=yearnodes)
yearadjacency.rename(index=yearnodeindex, inplace=True)
yearadjacency
# Out:
#                              agricultural residues  bio-oil  butanol  \
# agricultural residues                          0.0      0.0      0.0
# bio-oil                                        0.0      0.0      0.0
# butanol                                        0.0      0.0      0.0
# cellulosic ethanol                             0.0      0.0      0.0
# ethanol                                        0.0      0.0      0.0
# fermentation                                   0.0      0.0      0.0
# hydrolysis                                     0.0      0.0      0.0
# methanol                                       0.0      0.0      0.0
# pyrolysis                                      0.0      0.0      0.0
# agricultural waste                             0.0      0.0      0.0
# anaerobic digestion                            0.0      0.0      0.0
# biodiesel                                      0.0      0.0      0.0
# biogas                                         0.0      0.0      0.0
# fischer-tropsch                                0.0      0.0      0.0
# gasoline                                       0.0      0.0      0.0
# agriculture                                    0.0      0.0      0.0
# bioethanol                                     0.0      0.0      0.0
# biofuels from algae                            0.0      0.0      0.0
# enzymatic hydrolysis                           0.0      0.0      0.0
# fatty acid ethyl ester                         0.0      0.0      0.0
# oil extraction                                 0.0      0.0      0.0
# pellets                                        0.0      0.0      0.0
# algae                                          0.0      0.0      0.0
# algal oil extraction                           0.0      0.0      0.0
# biogasoline                                    0.0      0.0      0.0
# renewable fuel                                 0.0      0.0      0.0
# transesterification                            0.0      0.0      0.0
# animal fats                                    0.0      0.0      0.0
# animal manure                                  0.0      0.0      0.0
# animal waste                                   0.0      0.0      0.0
# biobutanol                                     0.0      0.0      0.0
# arundo donax                                   0.0      0.0      0.0
# gasification                                   0.0      0.0      0.0
# bagasse                                        0.0      0.0      0.0
# banna grass                                    0.0      0.0      0.0
# bark                                           0.0      0.0      0.0
# fast pyrolysis                                 0.0      0.0      0.0
# pressing                                       0.0      0.0      0.0
# barley straw                                   0.0      0.0      0.0
# barley                                         0.0      0.0      0.0
# biomass gasification                           0.0      0.0      0.0
# syng                                           0.0      0.0      0.0
# black liquor                                   0.0      0.0      0.0
# sugarcane bagasse                      0.0             0.0    0.0
# sugarcane                              0.0             0.0    0.0
# switchgrass                            0.0             0.0    0.0
# syngas from gasifier                   0.0             0.0    0.0
# sng                                    0.0             0.0    0.0
# syngas                                 0.0             0.0    0.0
# vegetable oil                          0.0             0.0    0.0
# waste vegetable oil                    0.0             0.0    0.0
# waste water                            0.0             0.0    0.0
# waste                                  0.0             0.0    0.0
# wheat straw                            0.0             0.0    0.0
# wheat                                  0.0             0.0    0.0
# willow                                 0.0             0.0    0.0
# wood chips                             0.0             0.0    0.0
# wood                                   0.0             0.0    0.0
# woody biomass                          0.0             0.0    0.0
# yard trimmings                         0.0             0.0    0.0
# yeast                                  0.0             0.0    0.0

# %%
for index, row in oneyear.iterrows():
    #if nodes.isin(row.source) and nodes.isin(row.target) :
    #print row['count']
    if row.source in yearnodes and row.target in yearnodes:
        yearadjacency.at[row.source,row.target] = row['count']
        yearadjacency.at[row.target,row.source] = row['count']
    else:
        print (row.source + ":" + row.target)
yearadjacency
# %store yearadjacency
# %store yearnodes
# Out:
# Stored 'yearadjacency' (DataFrame)
# Stored 'yearnodes' (list)

# %%
# %store -r nodes_clustered
nodes_clustered
# Out:
#                                       0  cluster
# 0                         vegetable oil        4
# 1                     woodwaste/bagasse        0
# 2                           natural gas       14
# 3                       various grasses       19
# 4                        nonedible oils       17
# 5                           animal fats       12
# 6                                 paper       16
# 7                        ponderosa pine       19
# 8                            grass seed       19
# 9                                   osb       14
# 10                          paper waste       12
# 11                             corn cob       13
# 12                       energy grasses       19
# 13                     logging residues       19
# 14                               willow       16
# 15                           crop waste       13
# 16                             firewood       13
# 17                             jatropha        4
# 18                    sugarcane bagasse       19
# 19                                sugar       14
# 20                                 wood       16
# 21                municipal solid waste       14
# 22                          banna grass       13
# 23                            waste oil       12
# 24                               barley       19
# 25                               starch        5
# 26                      coniferous wood        7
# 27                             corn oil       14
# 28                           wood waste        4
# 29                          corn stalks        4
# 30                        yellow grease       12
# 31                             molasses       19
# 32                            woodchips        7
# 33                           food waste        4
# 34                      citrus residues       17
# 35                           wood chips       11
# 36                       cotton residue       13
# 37                     industrial waste        7
# 38                          corn stover       14
# 39                            waste fat       17
# 40                  waste vegetable oil       13
# 41                               tallow       12
# 42                               sewage       13
# 43                           white pine       13
# 44                             hardwood        7
# 45                        loblolly pine       19
# 46                           miscanthus       19
# 47                                 palm       14
# 48                                 milo       11
# 49                                 bark        4
# 50                          agriculture       14
# 51                             textiles        7
# 52                          beef tallow       12
# 53                         animal waste       14
# 54                                 cobs       14
# 55                      forest residues       13
# 56                      grass clippings       19
# 57                              plywood       13
# 58                          dry biomass        4
# 59                 southern yellow pine       13
# 60                      free fatty acid        7
# 61                          trap grease       17
# 62   woody and agricultural by-products       19
# 63                 syngas from gasifier       16
# 64                            cellulose        5
# 65                                wheat       11
# 66                        organic waste       14
# 67                           oil plants       17
# 68                                 corn        4
# 69                        animal manure       14
# 70                                 dung       14
# 71                   agricultural waste       14
# 72                       elephant grass       19
# 73                biogas from landfills       17
# 74                   waste water sludge       14
# 75                                algae       11
# 76                           rice straw       19
# 77                         barley straw       19
# 78                           Giant reed       17
# 79                           rice hulls       19
# 80                           canola oil        7
# 81                                  msw       19
# 82                         digester gas       17
# 83                                seeds        4
# 84                                grain        7
# 85                     distillers grain       16
# 86                           sugar beet        7
# 87                        mixed biomass       13
# 88                        brewery waste       13
# 89                            triticale        7
# 90                             camelina        7
# 91                   cellulosic biomass       19
# 92                             plastics       13
# 93                          poultry fat       13
# 94                                straw       11
# 95                       water hyacinth       19
# 96                                 hogs       19
# 97                       beverage waste       11
# 98                           macroalgae        4
# 99                           sugar base       19
# 100                                 soy        5
# 101                       woody biomass        5
# 102                               maple       16
# 103                             bagasse       14
# 104                         wheat straw        4
# 105                            jathropa       17
# 106           medium density fiberboard        7
# 107                 biodegradable waste       13
# 108                 poplar/energy woods        1
# 109                                husk        7
# 110                                 fog       14
# 111                               waste       16
# 112                             soy oil        5
# 113                            oilseeds       19
# 114                           pal waste       16
# 115         grass straw and corn stalks       19
# 116                agricultural biomass        7
# 117                            glycerin       11
# 118                    used cooking oil        5
# 119                     hydrous ethanol        7
# 120                            seed oil        4
# 121                              manure       16
# 122                        shrub willow       13
# 123                              grains       19
# 124                              syngas       12
# 125                      particle board       13
# 126                        energy crops        5
# 127                          slash pine       12
# 128                               lemna       11
# 129                              lumber       19
# 130                            hog fuel        7
# 131               agricultural residues       16
# 132                               grass       19
# 133                             sorghum       17
# 134                          virgin oil       17
# 135                        rapeseed oil       17
# 136                         cooking oil        7
# 137                             sawdust       16
# 138                     sugarcane trash       19
# 139                         cheese whey       12
# 140                         corn/barley        2
# 141                         switchgrass       17
# 142                      yard trimmings       17
# 143                              stover       14
# 144                         douglas fir       19
# 145                     crude glycerine       12
# 146                        brown grease        4
# 147                         waste water       19
# 148                        garden waste       17
# 149                               yeast       19
# 150                                 oak       13
# 151                                pine       14
# 152                            forestry       11
# 153                           wood fuel       13
# 154                 mixed prairie grass       19
# 155                                whey        4
# 156                    lignocellulosics       19
# 157                   cellulosic sugars       19
# 158                             juniper       11
# 159                           sugarcane       17
# 160                          urban wood       19
# 161                            residues       16
# 162                    cotton gin trash       13
# 163                            rapeseed        5
# 164                        arundo donax       19
# 165              dedicated energy crops       19
# 166                        black liquor       11
# 167                          eucalyptus       11
# 168                               beets       19
# 169      non-cellulosic portions of sfw        3
# 170               refined vegetable oil       13
# 171                     vegetable waste       17
# 172                              poplar        7
# 173                            palm oil       17
# 174                               blend       16
# 175                       hybrid poplar       14
# 176                   hydrochloric acid       19
# 177                   aerobic digestion       16
# 178          consolidated bioprocessing       19
# 179                    methane recovery       19
# 180                     hydroprocessing       11
# 181                  biomass combustion       16
# 182                        gasification       13
# 183                enzymatic hydrolysis       19
# 184                  biogas productions       16
# 185                      oil extraction        4
# 186                bioenergy generation       14
# 187                              coking       12
# 188                            charring        4
# 189                                 cbp        7
# 190                           microwave        4
# 191                          bioforming       14
# 192                algal oil extraction       17
# 193                biomass gasification       16
# 194           black liquor gasification       16
# 195                      grate furnaces       16
# 196                            solvents        4
# 197                 fixed bed gasifiers       11
# 198             biochemical conversions        5
# 199                                 blg       16
# 200              alcoholic fermentation        4
# 201                     fischer-tropsch       16
# 202                       hydrotreating        5
# 203                 transesterification        5
# 204                algae oil extraction       11
# 205                        gas cleaning       11
# 206                        landfill gas       17
# 207                       pyrolysis oil       11
# 208          thermochemical conversions       16
# 209                      fast pyrolysis       14
# 210                           scrubbers       16
# 211                                 tbd        7
# 212                  plant cell culture       16
# 213                     acid hydrolysis       14
# 214               advanced fermentation       19
# 215                           pyrolysis       13
# 216                        liquefaction       16
# 217           gasification-fermentation       12
# 218                          hydrolysis       14
# 219             ft microchannel reactor        6
# 220                            pressing        7
# 221                          metathesis        4
# 222              fluidized bed furnaces        4
# 223                 anaerobic digestion       17
# 224                        fermentation       19
# 225                           catalysis        7
# 226                            furanics        7
# 227                              biodme       16
# 228              cellulosic heating oil        8
# 229                       succinic acid       17
# 230                  renewable jet fuel        5
# 231                    ethanol blending       16
# 232                         adipic acid        5
# 233                 renewable chemicals       12
# 234                                syng       13
# 235                       drop-in fuels       13
# 236            electricity from biomass       16
# 237                          bioplastic        5
# 238                          biobutanol       14
# 239                    eth from bagasse        9
# 240       cellulosic renewable gasoline       10
# 241                    advanced biofuel        7
# 242               renewable electricity       16
# 243                  renewable gasoline       11
# 244                            methanol       12
# 245                              biogas       11
# 246                  cellulosic ethanol       19
# 247                                 bdo       19
# 248                      nutriceuticals       16
# 249                             butanol       19
# 250                         biopolymers       16
# 251                                 sng       16
# 252                             bio-oil       13
# 253                 biofuels from algae       16
# 254                  cellulosic biofuel       14
# 255            celleth from wheat straw       15
# 256                           biodiesel       17
# 257                         biogasoline       11
# 258                                 lpg       16
# 259                    renewable diesel        4
# 260                             naphtha        4
# 261                             ethanol       19
# 262               methanol/then ethanol       18
# 263              fatty acid ethyl ester        7
# 264                                rdif       13
# 265                        polyethylene       14
# 266                  biodiesel blending       16
# 267                            bioresin       11
# 268                          bioethanol       19
# 269              biofuels for transport       14
# 270                 mixed alcohol fuels       16
# 271                            gasoline        4
# 272                      renewable fuel       19
# 273                                 pdo        4
# 274                       renewable jet        5
# 275                             pellets        7
# 276                biomass-based diesel       16
# 277                       mtg catalysis       20
# 278              polylutylene succinate       21
# 279                            potatoes       22
# 280   renewable diesel from animal fats       23

# %%
filename = 'terms_by_clusters.csv'
nodes_clustered.to_csv(filename, sep=',')

# %%
nodes
print(len(nodes))
# Out:
# 281

# %% [markdown]
# ## Write the file for D3

# %%
strjson = '{"nodes":['
for node in yearnodes:
    print node
    #print nodeindex(node)
    #print nodes_clustered.cluster[yearnodes.index('natural gas')]
    strjson = strjson + '{"name":"' + node + '","group":' + str(nodes_clustered.cluster[nodes.index(node)]) + '},'
#remove last comma from json
strjson = strjson[:-1]
print strjson
# Out:
# agricultural residues
# bio-oil
# butanol
# cellulosic ethanol
# ethanol
# fermentation
# hydrolysis
# methanol
# pyrolysis
# agricultural waste
# anaerobic digestion
# biodiesel
# biogas
# fischer-tropsch
# gasoline
# agriculture
# bioethanol
# biofuels from algae
# enzymatic hydrolysis
# fatty acid ethyl ester
# oil extraction
# pellets
# algae
# algal oil extraction
# biogasoline
# renewable fuel
# transesterification
# animal fats
# animal manure
# animal waste
# biobutanol
# arundo donax
# gasification
# bagasse
# banna grass
# bark
# fast pyrolysis
# pressing
# barley straw
# barley
# biomass gasification
# syng
# black liquor
# biodme
# blend
# bioplastic
# biopolymers
# gas cleaning
# naphtha
# catalysis
# cellulose
# cellulosic biomass
# cobs
# corn cob
# corn stalks
# corn stover
# corn
# biomass combustion
# renewable electricity
# dedicated energy crops
# digester gas
# distillers grain
# dry biomass
# energy crops
# energy grasses
# food waste
# forest residues
# forestry
# free fatty acid
# glycerin
# polyethylene
# solvents
# grain
# grains
# grass seed
# grass straw and corn stalks
# grass
# hardwood
# husk
# jatropha
# landfill gas
# lignocellulosics
# liquefaction
# macroalgae
# manure
# microwave
# msw
# natural gas
# lpg
# oak
# organic waste
# pal waste
# palm oil
# palm
# paper
# pine
# plastics
# poplar
# pyrolysis oil
# rapeseed oil
# rapeseed
# refined vegetable oil
# residues
# rice straw
# sawdust
# seed oil
# advanced biofuel
# seeds
# sewage
# sorghum
# soy
# starch
# stover
# straw
# sugar beet
# sugar
# sugarcane bagasse
# sugarcane
# switchgrass
# syngas from gasifier
# sng
# syngas
# vegetable oil
# waste vegetable oil
# waste water
# waste
# wheat straw
# wheat
# willow
# wood chips
# wood
# woody biomass
# yard trimmings
# yeast
# {"nodes":[{"name":"agricultural residues","group":16},{"name":"bio-oil","group":13},{"name":"butanol","group":19},{"name":"cellulosic ethanol","group":19},{"name":"ethanol","group":19},{"name":"fermentation","group":19},{"name":"hydrolysis","group":14},{"name":"methanol","group":12},{"name":"pyrolysis","group":13},{"name":"agricultural waste","group":14},{"name":"anaerobic digestion","group":17},{"name":"biodiesel","group":17},{"name":"biogas","group":11},{"name":"fischer-tropsch","group":16},{"name":"gasoline","group":4},{"name":"agriculture","group":14},{"name":"bioethanol","group":19},{"name":"biofuels from algae","group":16},{"name":"enzymatic hydrolysis","group":19},{"name":"fatty acid ethyl ester","group":7},{"name":"oil extraction","group":4},{"name":"pellets","group":7},{"name":"algae","group":11},{"name":"algal oil extraction","group":17},{"name":"biogasoline","group":11},{"name":"renewable fuel","group":19},{"name":"transesterification","group":5},{"name":"animal fats","group":12},{"name":"animal manure","group":14},{"name":"animal waste","group":14},{"name":"biobutanol","group":14},{"name":"arundo donax","group":19},{"name":"gasification","group":13},{"name":"bagasse","group":14},{"name":"banna grass","group":13},{"name":"bark","group":4},{"name":"fast pyrolysis","group":14},{"name":"pressing","group":7},{"name":"barley straw","group":19},{"name":"barley","group":19},{"name":"biomass gasification","group":16},{"name":"syng","group":13},{"name":"black liquor","group":11},{"name":"biodme","group":16},{"name":"blend","group":16},{"name":"bioplastic","group":5},{"name":"biopolymers","group":16},{"name":"gas cleaning","group":11},{"name":"naphtha","group":4},{"name":"catalysis","group":7},{"name":"cellulose","group":5},{"name":"cellulosic biomass","group":19},{"name":"cobs","group":14},{"name":"corn cob","group":13},{"name":"corn stalks","group":4},{"name":"corn stover","group":14},{"name":"corn","group":4},{"name":"biomass combustion","group":16},{"name":"renewable electricity","group":16},{"name":"dedicated energy crops","group":19},{"name":"digester gas","group":17},{"name":"distillers grain","group":16},{"name":"dry biomass","group":4},{"name":"energy crops","group":5},{"name":"energy grasses","group":19},{"name":"food waste","group":4},{"name":"forest residues","group":13},{"name":"forestry","group":11},{"name":"free fatty acid","group":7},{"name":"glycerin","group":11},{"name":"polyethylene","group":14},{"name":"solvents","group":4},{"name":"grain","group":7},{"name":"grains","group":19},{"name":"grass seed","group":19},{"name":"grass straw and corn stalks","group":19},{"name":"grass","group":19},{"name":"hardwood","group":7},{"name":"husk","group":7},{"name":"jatropha","group":4},{"name":"landfill gas","group":17},{"name":"lignocellulosics","group":19},{"name":"liquefaction","group":16},{"name":"macroalgae","group":4},{"name":"manure","group":16},{"name":"microwave","group":4},{"name":"msw","group":19},{"name":"natural gas","group":14},{"name":"lpg","group":16},{"name":"oak","group":13},{"name":"organic waste","group":14},{"name":"pal waste","group":16},{"name":"palm oil","group":17},{"name":"palm","group":14},{"name":"paper","group":16},{"name":"pine","group":14},{"name":"plastics","group":13},{"name":"poplar","group":7},{"name":"pyrolysis oil","group":11},{"name":"rapeseed oil","group":17},{"name":"rapeseed","group":5},{"name":"refined vegetable oil","group":13},{"name":"residues","group":16},{"name":"rice straw","group":19},{"name":"sawdust","group":16},{"name":"seed oil","group":4},{"name":"advanced biofuel","group":7},{"name":"seeds","group":4},{"name":"sewage","group":13},{"name":"sorghum","group":17},{"name":"soy","group":5},{"name":"starch","group":5},{"name":"stover","group":14},{"name":"straw","group":11},{"name":"sugar beet","group":7},{"name":"sugar","group":14},{"name":"sugarcane bagasse","group":19},{"name":"sugarcane","group":17},{"name":"switchgrass","group":17},{"name":"syngas from gasifier","grou ...

# %%
stredges = '],"links":['
for source in yearnodes:
    #print source + "--------------"
    for target in yearnodes:
        #print target
        if yearadjacency[source][target] > 0:
            #strpair = '{"source":' + source + ',"target":' + target + ',"value":' + str(adjacency[source][target]) + '},'
            strpair = '{"source":' + str(yearnodes.index(source)) + ',"target":' + str(yearnodes.index(target)) + ',"value":' + str(yearadjacency[source][target]) + '},'
            stredges = stredges + strpair
stredges = stredges[:-1]
stredges = stredges + "]}"
print stredges
# Out:
# ],"links":[{"source":0,"target":1,"value":1.0},{"source":0,"target":2,"value":1.0},{"source":0,"target":3,"value":1.0},{"source":0,"target":4,"value":3.0},{"source":0,"target":5,"value":2.0},{"source":0,"target":6,"value":1.0},{"source":0,"target":7,"value":1.0},{"source":0,"target":8,"value":1.0},{"source":1,"target":0,"value":1.0},{"source":1,"target":8,"value":7.0},{"source":1,"target":15,"value":1.0},{"source":1,"target":22,"value":1.0},{"source":1,"target":26,"value":1.0},{"source":1,"target":27,"value":1.0},{"source":1,"target":34,"value":1.0},{"source":1,"target":35,"value":1.0},{"source":1,"target":36,"value":2.0},{"source":1,"target":44,"value":3.0},{"source":1,"target":51,"value":1.0},{"source":1,"target":68,"value":1.0},{"source":1,"target":69,"value":1.0},{"source":1,"target":76,"value":1.0},{"source":1,"target":77,"value":1.0},{"source":1,"target":89,"value":1.0},{"source